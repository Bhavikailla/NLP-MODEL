# %%
 # !nvidia-smi
# Out:
# Mon Dec  4 05:55:20 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Finetune Llama-2-7b on a Google colab
#
# Welcome to this Google Colab notebook that shows how to fine-tune the recent Llama-2-7b model on a single Google colab and turn it into a chatbot
#
# We will leverage PEFT library from Hugging Face ecosystem, as well as QLoRA for more memory efficient finetuning

# %% [markdown]
# Setup
#
# Run the cells below to setup and install the required libraries. For our experiment we will need accelerate, peft, transformers, datasets and TRL to leverage the recent SFTTrainer. We will use bitsandbytes to quantize the base model into 4bit. We will also install einops as it is a requirement to load Falcon models

# %%
# !pip install -q -U trl transformers accelerate git+https://github.com/huggingface/peft.git
# !pip install -q datasets bitsandbytes einops wandb
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.9/133.9 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 33.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.9/100.9 kB 13.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 12.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.9 MB/s eta 0:00:00
#   Building wheel for peft (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 95.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 24.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.8/252.8 kB 26.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.3 MB/s eta 0:00:00

# %% [markdown]
# #**DATASET**

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from datasets import load_dataset

dataset_name = 'yahoo_answers_qa'
dataset = load_dataset(dataset_name, split='train')
# Out:
# Downloading builder script:   0%|          | 0.00/2.76k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/1.59k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/3.66k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/49.4M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/87362 [00:00<?, ? examples/s]

# %%
print(dataset)
# Out:
# Dataset({
#     features: ['id', 'question', 'answer', 'nbestanswers', 'main_category'],
#     num_rows: 87362
# })

# %%
print(dataset[0])
# Out:
# {'id': '2020338', 'question': 'Why did the U.S Invade Iraq ?', 'answer': "A small group of politicians believed strongly that the fact that Saddam Hussien remained in power after the first Gulf War was a signal of weakness to the rest of the world, one that invited attacks and terrorism. Shortly after taking power with George Bush in 2000 and after the attack on 9/11, they were able to use the terrorist attacks to justify war with Iraq on this basis and exaggerated threats of the development of weapons of mass destruction. The military strength of the U.S. and the brutality of Saddam's regime led them to imagine that the military and political victory would be relatively easy.", 'nbestanswers': ["A small group of politicians believed strongly that the fact that Saddam Hussien remained in power after the first Gulf War was a signal of weakness to the rest of the world, one that invited attacks and terrorism. Shortly after taking power with George Bush in 2000 and after the attack on 9/11, they were able to use the terrorist attacks to justify war with Iraq on this basis and exaggerated threats of the development of weapons of mass destruction. The military strength of the U.S. and the brutality of Saddam's regime led them to imagine that the military and political victory would be relatively easy.", 'Because there is a lot of oil in Iraq.', 'It is tempting to say that the US invaded Iraq because it has lots of oil, but the US is not a country in a deep economic problem that capturing other country’s oil is an actual need for survival. It is more likely that the Iraq invading Kuwait scenario would fall under that assumption.. I think that the US government has come to a conclusion that we are on the verge of a war of religions, or more likely ideologies. It would be presumptuous to try and determent a one cause to the coming war. . I think that the world wide spread of the media with its many forms (Cable, Satellite, Internet, etc.)  have pushed the Moslem regimes to the extreme, fearing that secularity and democratic influence is penetrating their country and will result in an up raising against them. One of the best way to maintain the power that you have and even gain more of it, is by hatred. When the common man is occupied hating an outside enemy, its hatred is kept out side the county and would not be directed towards the regime. . So- I believe that the US understands that the fanatic Moslem regimes have already started a war on the democratic world and now is the time to try a fight it.. . So why invade Iraq? Because it is a huge, week Moslem country that thought to be easy to defeat. . This is exactly the same reason why Afghanistan was first and Syria is next in line.', 'I think Yuval is pretty spot on. It\'s a proving ground and a focal point for terror activity that\'s not on American soil. And, because no one liked Saddam Hussein, no other countries (even in the Middle East) were about to rise up and join his side.. . Rabid speculation: now the Pentagon has a model that says it takes ~5 years, ~$200B and ~2,000 casualties to "rebuild" a dictatorship into a democracy. Who\'s next on the list?'], 'main_category': 'News & Events'}

# %% [markdown]
# # Loading the Model

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, AutoTokenizer

model_name = "TinyPixel/Llama-2-7B-bf16-sharded"
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    trust_remote_code=True
)
model.config.use_cache = False
# Out:
# config.json:   0%|          | 0.00/626 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/14 [00:00<?, ?it/s]
# pytorch_model-00001-of-00014.bin:   0%|          | 0.00/981M [00:00<?, ?B/s]
# pytorch_model-00002-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# pytorch_model-00003-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# pytorch_model-00004-of-00014.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# pytorch_model-00005-of-00014.bin:   0%|          | 0.00/944M [00:00<?, ?B/s]
# pytorch_model-00006-of-00014.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# pytorch_model-00007-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# pytorch_model-00008-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# pytorch_model-00009-of-00014.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# pytorch_model-00010-of-00014.bin:   0%|          | 0.00/944M [00:00<?, ?B/s]
# pytorch_model-00011-of-00014.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# pytorch_model-00012-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# pytorch_model-00013-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# pytorch_model-00014-of-00014.bin:   0%|          | 0.00/847M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/14 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# tokenizer_config.json:   0%|          | 0.00/676 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/411 [00:00<?, ?B/s]

# %%
from peft import LoraConfig, get_peft_model

lora_alpha = 16
lora_dropout = 0.1
lora_r = 64

peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM"
)

# %%
from transformers import TrainingArguments

output_dir = "./results"
per_device_train_batch_size = 4
gradient_accumulation_steps = 4
optim = "paged_adamw_32bit"
save_steps = 100
logging_steps = 10
learning_rate = 2e-4
max_grad_norm = 0.3
max_steps = 100
warmup_ratio = 0.03
lr_scheduler_type = "constant"

training_arguments = TrainingArguments(
    output_dir=output_dir,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    fp16=True,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=True,
    lr_scheduler_type=lr_scheduler_type,
)

# %%
from trl import SFTTrainer
max_seq_length = 3000

trainer = SFTTrainer(
    model=model,
    train_dataset=dataset,
    peft_config=peft_config,
    dataset_text_field="question",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_config.py:141: UserWarning: The `optimize_cuda_cache` arguement will be deprecated soon, please use `optimize_device_cache` instead.
#   warnings.warn(
# Map:   0%|          | 0/87362 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:247: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(

# %%
for name, module in trainer.model.named_modules():
    if "norm" in name:
        module = module.to(torch.float32)

# %% [markdown]
# # train the model

# %%
trainer.train()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/content/wandb/run-20231204_060600-gk4603p8</code>
# Syncing run <strong><a href='https://wandb.ai/illabhavika/huggingface/runs/gk4603p8' target="_blank">wise-snowball-5</a></strong> to <a href='https://wandb.ai/illabhavika/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/illabhavika/huggingface' target="_blank">https://wandb.ai/illabhavika/huggingface</a>
#  View run at <a href='https://wandb.ai/illabhavika/huggingface/runs/gk4603p8' target="_blank">https://wandb.ai/illabhavika/huggingface/runs/gk4603p8</a>
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 05:05, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>4.008500</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>3.665400</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>2.993200</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>3.228100</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>3.882800</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>3.559600</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>3.653500</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>3.076400</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>3.070700</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>3.215500</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=100, training_loss=3.435364875793457, metrics={'train_runtime': 364.5044, 'train_samples_per_second': 4.39, 'train_steps_per_second': 0.274, 'total_flos': 901462064627712.0, 'train_loss': 3.435364875793457, 'epoch': 0.02})

# %%
model_to_save = trainer.model.module if hasattr(trainer.model, 'module') else trainer.model  # Take care of distributed/parallel training
model_to_save.save_pretrained("outputs")

# %%
dataset['question']
# Out:
# ['Why did the U.S Invade Iraq ?',
#  'How to get rid of a beehive?',
#  "Why don't European restaurants serve water?",
#  'Why hybrid cars gas mileage is better in city ?',
#  'Can someone explain the theory of e=mc2?',
#  'For colIege admission, is it better to take AP classes and get Bs or easy classes and get As?',
#  "Why didn't anyone send more buses to the Superdome earlier?",
#  'how do Elephants communicate?',
#  'why does dogs, which have an excellent smell sense, needs to stuck their nose into whatever they',
#  'How to boil lobster?',
#  'what are the base colors?',
#  'Can you give advice on how to pick watermelons?',
#  'What meats are suited for a slow cooker?',
#  'Why is it considered unlucky to open an umbrella indoors?',
#  "What is bubble tea and what's in it?",
#  'Why do we only drink eggnog during Christmas?',
#  "What's the difference between European butter and regular butter?",
#  'If light travels faster than sound, then why do we hear sound first and then see picture when we turn on TV ?',
#  'How do I write a resume?',
#  'Why do men wear neckties?',
#  "How does China view North Korea's claimed nuclear weapons capability?",
#  'Why are handicapped bathroom stalls always built at the end of the restroom?',
#  "What's the ugliest car on the road?",
#  'Why do people put salt around the glass when drinking Margarita?',
#  'What is CGI?',
#  "Why can't I get used to console-style controls in FPS games?",
#  'Why are blueberries so good for your health?',
#  'Why do we drive on the parkway...?',
#  'What does "buck naked" mean?',
#  'What is the meaning of life?',
#  "Why won't drivers use thier turn signals?",
#  'Why do women get PMS?',
#  'What should you do when you apply to a university and you get put on a waiting list?',
#  "Why doesn't Yahoo mail beta support SafarI on Mac?",
#  'What happened to the missing 18.5 minutes on the Watergate tapes?',
#  'How do I convert metric to U.S units?',
#  'How should I encrypt/pw protect my backup files on an external harddrive for easy recovery on any machine?',
#  "Why hasn't anyone found a cure for the common cold yet?",
#  'What is the difference between Askers and Answerers?',
#  'Which Internet browser is the best and why?',
#  "if i have 2 pc's that have a wireless connection how do i get both pcs 2 share information and share a printer",
#  'I have 2 40 gig hard drives,win98se,and I want to get a new drive say 160 or more,how do I get the info switch',
#  'How do you use dental floss?',
#  'How do you save online movies for play later?',
#  'HOW CAN I GET A JOB?',
#  'how do I stop pop ups from Best Offers?',
#  'Why is there terrorism?',
#  'I am not able to run my messenger from my desktop so i need to know why and what si the problum?',
#  'why do clouds turn dark when its about to rain?',
#  "Why isn't calicum carbide used in fuel cells?",
#  'what is the answer to: P=2L + 2w for w ?',
#  'how to become a perfect hardware engineer as i am undergoing btech in CSE in second year?',
#  'why chicory is added to coffee?',
#  'How do you vote in Iraq?',
#  'what does a 4\'x8\'- 1/2" sheet of drywall weigh...one sheet, not the double?',
#  'what is meant by protocol?',
#  'How to convert a pdf document to word document without losing the formatting?',
#  'How can I as a teenager reduce my car insurance premiums?',
#  'Do you believe in reincarnation?And why?',
#  'what is a "fruit baller"?',
#  'how i eraise the old words in my search bar?',
#  'Why do babies have to come out head first?',
#  'how is a digital camera work ?',
#  'How do I access my Yahoo mail settings?',
#  'how can you connect ur ps2 to ur computer?',
#  'WHy is my son gay?',
#  'how is the job market for ophthalmologists in washington state?',
#  'Why is it that dogs whine?',
#  'how can you tell if someone has opened your email?',
#  'What are the chances that Israel launches an attack to prevent Iranian nuclear ambitions?',
#  'Why are gold prices going up?',
#  'How can I make free - full free- International calls ( from and to countries out of USA)?',
#  'What is the difference between Blog and Podcast ?',
#  'how do you intergrate ssl with a web based site?',
#  'Why is the <link /> element the unsung hero of (X)HTML?',
#  'Why do people steal the baby jesus at christmas?',
#  'Do you think Draco Malfoy will turn to the order of the Pheonix?',
#  'how is the climate in chennai city?',
#  "how to apply for a credit card through Lebanon's super wal-mart?",
#  'how do u transfer mail that have been received from an account to another account?',
#  'HOW DO I CRASH MY LOST NOKIA 7610 USING IMEI ?',
#  'what does the french word langap mean?',
#  'my apple ipod 30 gig just locked up when i pluged it in why?',
#  'what is the difference between ketchup and sauce?',
#  'How do I make it so I am invisible when playing games?',
#  'what is the difference between perfume and cologne?',
#  'Why do we have social security numbers?',
#  'what is networking?',
#  'Why is my Dove making weird noises?',
#  'what is trillian and what is the web address?',
#  'Why do people still make secret admirer letters?',
#  'what is internet?',
#  'Why does my cat love vegetables?',
#  'How much money should someone with BSc in Biochemistry and Biotechnology make?',
#  'What are the factors of plant growth?',
#  'How to apologize to your inferior if you were the general manager ?',
#  'how hot is jesse mccartney to u from 1-100000?',
#  'how can put a question to vote?',
#  'What are the rules and regulations on selling home brewed beer at bars?',
#  'How can I clean a suede jacket?',
#  'How do i use RUP(rational unified process) to plan my project?',
#  'What happens to Flick on the playground?',
#  'Why is yawning contagious?',
#  'what does "this page cannot be displayed" mean?',
#  'How do I find out a guys email address?',
#  'how do you like your eggs?',
#  'how to get rid of static electricity?',
#  'how can i listen to my yahoo launchcast on my home stereo?',
#  'What is the bad effect of not having sex regularly?',
#  'what is daegan wicca?',
#  'Why do popes choose a new name for themselves?',
#  'While downloading from any site how can we know if its safe?',
#  'Why are most education majors in elementary education?',
#  'what are the benefits to buying a used car?',
#  'how do you delete the history in the yahoo search bar?',
#  'What is tamiflu?',
#  'how can i get a horizontal line in LaTeX ?',
#  'why is the middle finger considerd a bad finger?',
#  'how do you treat cats ear mites without going to a vet?',
#  'how do you print grid lines on a spread sheet?',
#  'People are sending foul language in subject line of email how can I stop them from continuing?',
#  "Why don't they make more blue soda?",
#  'Where did the phrase "rule of thumb" come from?',
#  "why doesn't yahoo delete SPAM after 1 month, like the ad says?",
#  'What is the safest way to clean a computer laptop screen?',
#  'i wanted to know if there is a website in teaching how to file in alphabetical order?',
#  "What is the best way to treat constant dry eyes (otherwise, they're fine)?",
#  'Why does the smell of cigarette smoke make me sick?',
#  'how do I change my home page back to sbc dsl?',
#  'What are ID3 tags?',
#  'how to drive in ice & snow?',
#  'why does my computer  turn istself off for no reason?',
#  'How do you convert a conventional gas engine to run off of garbage or vegetable oil?',
#  'how do the states directly amend the u.s consitution?',
#  'how to turbo charge a chevy tbi v8?',
#  'How can we make friends group here on yahoo answers?just how?',
#  'Do I have to buy Dell cartridges for my Dell printer?',
#  'how abs works?',
#  'What is the quantum time-travel theory?',
#  'how english became the common language in world?',
#  'How can I safely open a geode?',
#  "Why does the computer take so long to load if it doesn't have a virus?",
#  'How good are the "foam mattress"?',
#  'Why are there so many religions?',
#  'WHY PEOPLE STEAL?',
#  'How do I erase all personal data?',
#  'what are the factors that determine the hoursduring a telecoomunication network available?',
#  'How can i use finger sirvice with port 29?',
#  'what is delegent mean?',
#  'how do you move itunes to a new computer without using an ipod?',
#  'Why do people have ten fingers and ten toes?',
#  'How did they decide how many time zones there were going to be and where the lines to divide them would be?',
#  'how to see how much net has been used?',
#  'How can I get my title deed after I lost it?',
#  'How might I host a VPN in windows XP pro?',
#  'why is the sky blue?',
#  "How can I get someone's address that has been deployed to Iraq?",
#  "What's the eye on the dollar , means ?",
#  'DOES SODA HELP STOP STOMACH BLOATING ?WHY?',
#  'What contents are in an official high school transcript?',
#  'what is the reason for life?',
#  'How do I temporarily allow pop ups?',
#  'What does in absentia mean?',
#  'What does the new EU law about data retention really mean to us?',
#  'Why do most girls enjoy being barefoot at home?',
#  'Why are truffles so expensive?',
#  'why are dimes smaller than nickels?',
#  'How can i make my pc a 2 system pc with 2 hard drives?',
#  'how do i sign up for school online at Grand Rapids Community College?',
#  'what is tcp/ip?',
#  'What causes back and chest pain in teen?',
#  'how come you can only answer somany questions per day?',
#  'what is VoIP?',
#  'why is the sky blue?',
#  'How do I sign up for Gmail?',
#  'What is the meaning of life?',
#  'why did God allow Lucifer to have his way?',
#  'what causes eye stys ?',
#  'how do you cook an apple pie?',
#  "What is 'applied strategy management'?",
#  'Does our sense of taste change as we age?',
#  'How do freighters communicate with each other and with authorites on land?',
#  'What is the meaning of life?',
#  'what is a s-curl?',
#  'What are the equipments that pediatrician uses to look inside the ears and for eyes?',
#  'What is "googlebombing"?',
#  "What's the fastest way to loose belly fat?",
#  'how do i install front usb 2.0 ports?',
#  'how to stop rooster from waking me up?',
#  'how do i delete my recent search list in the yahoo browser?',
#  'how can  i not b so out of breath?',
#  'How do I use k-means clustering to group observations?',
#  'how do you turn a voice memo into a ringtone for the LG c2000?',
#  'What is pubic hair for?',
#  "Why don't we snore when we are awake?",
#  'what are the benefits of using an electric shaver?',
#  'how do i delete search words?',
#  'What is the difference between foam soap and regular liquid soap?',
#  'what is the difference between XSL and CSS?',
#  'Why does people from different countries have different accents when speaking English?',
#  'What is the Difference between Tylenol and Asprin?',
#  'why is Uranus out of place?',
#  'how do I pay the church for performing a memorial service?',
#  'why salt will be spread on snowy days?',
#  'how do i delete username and password, it automatically comes while i try to open my mail account(google, yah)',
#  'i have mucus in the back of my throat how can i get rid of it?',
#  'how to find out if someone send you money from western union?',
#  'How do I choose a career?',
#  'What is the derivative of tangent?',
#  "I have a symbian phone and suddenly I can't play some midi files, why?",
#  'What is Obsessive Compulsive Disorder?',
#  'how 2 travel to california with my family 4 vaccation?',
#  'How do you get rid of stretchmarks?',
#  'what is the predicate logic?',
#  'How do i send a message to a 360 user from my 360 page?',
#  'what is sound card in computers?',
#  'How do you define a Christian Fanatic?',
#  "when selling on e-bay how do i make sure my item stays in the front pages so i'll sell?",
#  'how do i make friends?',
#  'How does my business get set up to accept health insurance?',
#  'Why is there not a list of users with the most points for Yahoo Answers?',
#  'What is Mouloukheih?',
#  'What does germination mean?',
#  'How does the Iraq war compare to the Vietnam war?',
#  "How do fire act in 'zero gravity'?",
#  'How to become a rich?',
#  'Why cant I play games?',
#  'how I can add_bot to my counter strike 1.5 series ( computer game )?',
#  'What is genital herpes?',
#  "Where does the expression 'dead as a doornail' come from, and what does it actually mean?",
#  'how can i find BISTO POWDER in Ohio.. to buy?',
#  'Why are man hole covers round ?',
#  'what is orthognal?',
#  'Why do people put plasticforks in someones yard?',
#  'what is the meaning of romance?',
#  'How can I get the monster out from under my bed?',
#  'How do I get a $250,000 job by working 9 to 5, five days a week?',
#  'Why does my voltage in my Truck go low and  barely start after driving for a while?',
#  'What are the differences between Christianity and Catholicism?',
#  'Why does milk spoil easily?',
#  'How high can a gas filled balloon travel upward?',
#  'How to store a meat grinder?',
#  'what is the meaning of life besides 42?',
#  'Whats the difference between Rat and mouse?',
#  'How do I put the fun back in my life?',
#  'I am doing a study for bible study and I want to know how do Leviathan and King Triton connected?',
#  'How important is a removable battery in an MP3 player?',
#  'how do i get some info for insrevice for nurse aide?',
#  'Why is the Monday after New Years a holiday?',
#  'How to find my IP Address?',
#  'Is the remote control central locking safe and secure?How do they work?',
#  'what is graphical method?',
#  'what is existential reality?',
#  'Why is the inside of a potato chip bag always foil?',
#  'what is satayhagraha and swarja?',
#  'what does the name michael mean?',
#  'Why is Portuguese from Portugal and Brazil spoken differently?',
#  'what is the meaning of life?',
#  'Im a bisexual,how can I change myself?',
#  'why is yawning contagious?',
#  'Why is it said, that a Cat Has Nine Lives?',
#  'Why is the oldest child the most neglected?',
#  "what's the scariest weather situation you've experienced?",
#  "What's the meaning of life?",
#  'What are some rules for secret santa?',
#  'What is a Cayman and what does it look like?',
#  'Why does Paul Wall have a blangin grill?',
#  'why and how do fireworks emit different colors and have different forms?',
#  "What's the weather like in Cancun in February?",
#  'What is the proper way to break-in a motorcycle?',
#  'why do my front brakes make a grinding noise when I brake?',
#  'how do I know if my chanel handbag is authentic?',
#  'why is my labium majora swollen?',
#  'Can someone explain how to properly use "farther" and "further" in a sentence?',
#  'What is a theopneust?',
#  'WHAT IS RESPONSIBILITY?',
#  'How cold does it it get in the artic cirlce?',
#  'What is the real purpose/benefit of the US to issue green cards for thousands foreigners annually?',
#  'What is the difference between Scheme and LISP?',
#  'what do mormons believe in?',
#  'What is the difference between a frequency and a channel when using a police scanner?',
#  'what is blood in my stool an indication of?',
#  'how do you use myspace at school if its blocked?',
#  'How can I break my habit of sneaking chocolates and sweets?',
#  'Why does it seem like the court system is set up to protect criminals?',
#  'Know an easy way to remember when to use affect and effect?',
#  'What are the significant differences between olive, vegetable, and peanut oil?',
#  'How come San Diegans are so dull witted and rude?',
#  'What percentage of Mac users know how to write programs in AppleScript?',
#  'how do you make email go faster?',
#  'what are the differences between a humidifier and a vaporizer?',
#  'How do I stop/block a email from being received by my address book from getting through?',
#  'I have 2 xboxs and i was wondering how do i system link them for playing multiplayer on Mech Assault 2 Lone wo',
#  'why should we not keep the confederate flag?',
#  'How do I know if it is necessary to get my electronic product to be FCC certified?',
#  'why are nurses mostly fat?',
#  'Why most of indian muslims are using term Khan at the end of their names?',
#  'Why does asparagus make your pee smell funny?',
#  'Why there are no french cars in the USA?',
#  'How do I stop my websites hit counter from counting my visits?',
#  'How can I do survey what customer thinking to my fine dining?',
#  'why do black people argue that jesus was black?',
#  'What is the difference between immigrant and emigrant?',
#  'What causes the price of gold to go up and down?',
#  'What do you do if your friend went up to another friend and stated everything she hated about her?',
#  'How do I move the taskbar on my XP desktop?',
#  'how can i get leads on selling pianos?',
#  'how to implement tagging (in a new project)?',
#  'Why do British people cheerio when they say good bye and how come we got cheerio as cereal?',
#  'How do I get the job back when I was fired?',
#  'my yahoo messenger wont come open ... why ?',
#  'Why is sudoku so addictive?',
#  'I cannot see my yahoo tool bar why?',
#  'what is the difference between domestic and foriegn policy?',
#  'What is the best Cruise Line and why?',
#  'Why do my tires overheat?',
#  'How to choose the right CPU?',
#  'Why is buying a car so freaking hard?',
#  'How do I register a domain name?',
#  'how i can buy a home in usa without money?',
#  'What is dieing like?',
#  'how does a mail qualify to be a spam?',
#  'How do flamingos fit into the bird group?',
#  'how do i contact usaa bank in san antonio to sign in and view account securely?',
#  'how do I cure an alaskan malamute from chewing bedspreads?',
#  'What do you mean by an applet?',
#  'how do you start a 94-96 ford explorer?',
#  'im not able to play any games on yahoo why?',
#  'Is The Da Vinci Code worth reading and why?',
#  'How I can I become a beta tester for Microsoft?',
#  'How may I call someone from my computer to their regular telephone?',
#  'why isnt portugual part of the latin flags and if it is please explain why or why not?',
#  'what is distributed computing?',
#  'How to make a muslin backdrop?',
#  'Why does the temperature drop when daybreak occurs?',
#  'how is it living in jail?',
#  'how do i shut off programs that start when pc starts?',
#  'how do i remove tsm008 from my computer?',
#  'how do you pronounce the word "hew"?',
#  'How do I get salon cruise ship employment?preferably U.S. agencies?',
#  'how do you get rid of bags under your eyes without having them removed surgically?',
#  'What is waste reduction?',
#  'why do dogs walk around in circles before they lay down?',
#  'what is broadband?',
#  'On Sonic the hedgehog 2 how do you fly the kite in the second stage?',
#  'why do wwe have eyebrows?',
#  'what is central hyperalgesia?',
#  'Why do men have nipples?',
#  'how do i clean the lense on my digital camera?',
#  'how do i see my past Q&A Activites?',
#  'Why do you log on to answers?',
#  'how do achaeologist find remains?',
#  'what is a memory door on a pda?',
#  'what is the difference between exorcism and multiple personality?',
#  'what is a splog?',
#  "how come yahoo mail says i have one new message, when i don't?",
#  'How do I know if I have mononucelosis or just a common cold?',
#  'How do you get out dungeon without using the wizards key?',
#  'Why do some people had outties belly buttons?',
#  'why khidmat negara web cannot open?',
#  'What percent of students that apply to college actually graduate and get a job in their field of study?',
#  'what are mycotoxines?',
#  'why is it when someone yawns , we automatically yawn right after ?',
#  "Why have have we not been contacted by et's yet?",
#  'What is the moral in thr book Da Vinci Code?',
#  'why do boys have penisis and girls have vaginas?',
#  'from process engineering,what is the process significance of paint production?',
#  'how do you make fragrance oil for candles?',
#  'what is foi groi?',
#  'what is 750ml in standard measurement?',
#  'the difference between deduction and reduction?',
#  'how do I insert a graphic into my email signature?',
#  'what does ghetto mean?',
#  'how does the United States sanction Cuba, but can have a base in Guantanamo, Cuba?',
#  'If a word in the dictionary were misspelled, how would we know?',
#  'Why is the Netherlands also called Holland?',
#  'how to enable javascript?',
#  'what is abdominal compartment syndrome?',
#  'how do i bottle raise a pit bull puppy?',
#  'Why do some people back in to parking spaces?',
#  'how can i go to irian jaya from Bali or Jakarta?',
#  'how do you avoid temptation?',
#  'How do you fight laziness?',
#  'How does cider vinigar work to reduce weight?',
#  'What is Turkish delight?',
#  'How important is consent in professional practice?',
#  'what is the difference between struts and shock absorters?',
#  'what is the answer to (4x + 1) + ( -3x + 9 )?',
#  'How does ground black pepper affect the melting of ice?',
#  'how do you file receipts on your tax returns?',
#  'how are taxes taken out of my paycheck?',
#  'how do i play pitfall on x-box?',
#  'How do you explain hundreds of fulfilled prophecies in the bible?',
#  'What is "single sideband" radio, and what do I need to hear it?',
#  'Why does my cat freak out at seemingly nothing?',
#  'How do you draw a portrait of William Howard Taft?',
#  'Using the bible mankind traces back only thousands of years when Adam was created but Dinos are older How then',
#  "Why don't I have an asthma attack during sex?",
#  'How do I make yogurt from powdered instant milk?',
#  'why does wood crackle when it burns?',
#  'my dog has bad gas, how should i get rid of it?',
#  'How do I send an email on yahoo, and not have my name show as the sender until email is opened?',
#  'How do you connect a computer to a television monitor?',
#  'Why firms must deduct minority interest earnings from profit after tax of group earnings?',
#  'How did the planet Pluto get its name?',
#  'u.s. is being called on the matt by the u.n. for torture.how about oil for food program?',
#  'How does someone get pneumonia?',
#  'why do they have braille on drive-thru atms?',
#  'How do I use my JVC GRDF550 as a webcam?',
#  'How do I win at the lottery?',
#  'how do i get rid of dry patches of skin on my legs?',
#  'What is the meaning of the word Movant?',
#  'why are americans so ignorant about the rest of the world?',
#  'what is a rootkit?',
#  'what is actaul meaning of "once in blue moon"?',
#  'How do I get music onto my myspace page?',
#  'how to cheat at virtual pool 3?',
#  'Why Indian restaurants in USA are not popular like Thai restaurants ?',
#  'what medication can you priscribe for the cure of typhoid fever in a patient?',
#  'how can i find a job on a cruise ship?',
#  'What is an inverted yield curve?',
#  'Could u pls explain me in detail what is indemnity insurance?',
#  "Why don't we hear sonic boom's anymore?",
#  'What does the term "google" mean?',
#  'how do i get rid of skin tags?',
#  'how do i make poker chip labels?',
#  'How can a clear earwax out of my ear?',
#  'WHAT IS COMPETITORS NOISE IN MARKETING MANAGEMENT?',
#  'Why do I get notified on yahoo messenger that I have email, and when I sign in to check I have none?',
#  'How do I get rid of winfixer?',
#  'What are those pink spots in the snow?',
#  'How can I speed up my metabolism to burn fat?',
#  'Why is there online chat rooms?',
#  'why do i get double email from a group?',
#  'how do i set up a database using microsoft word?',
#  'how is geothermal power generated?',
#  'how hot is a burning candle?',
#  'how to write to an SD card using pixma mp130?',
#  'How do I send thanks when a person answers a question?',
#  'why doesnt the us import more canadian oil?',
#  'what is the process to get oil from mirco-algae?',
#  'Why does dumb today mean stupid, when itinitially meant only inable to speak?',
#  'Why do people like to post questions about sex in a public forum?',
#  'why    are cats  so cute?',
#  'how do i download music into my library?',
#  'what is the meaning of death?',
#  'Why is there tears when we yawn?',
#  'What do Independents believe in USA ?',
#  'What is the 2006 Social Security "Taxable Wage Base"?',
#  'How can I improve my credit?',
#  "How do i check my Yahoo Voicemail if I don't have a telephone line connected to my computer?",
#  'How can I buy and ship a computer to Argentina?',
#  'why do men have nipples?',
#  'What is the meaning of the expression, "saw whipped"?',
#  'What is sustainable development?',
#  'can anybody tell  me how to network 2 and more computers for file and resource sharing?',
#  'How do I become a Firefighter?',
#  'how to get from SSS an employment history using the internet?',
#  'how to convert a jpeg file to word format?',
#  'What is the difference between a condominium & a co-op?',
#  'How to become wealthy?',
#  "What's the difference between a cook's knife and a chef's knife?",
#  'what is chip?',
#  'Why is fire hot?',
#  'How can we stop global- warming?',
#  'What are technical differeces between Conclusion and Findings in Bussines Communication?',
#  'WHY DO PEOPLE BUY WATER WHEN ITS FREE?',
#  'what is cyclsporin?',
#  'What is the difference between lager & beer?',
#  'how do I get free business cards that I can make myself?',
#  'how do I find out if I have an arrest warrant?',
#  'How can I get Internet Explorer to work after I have installed Netscape 8?',
#  'what is yahoo?',
#  'How can I reactivate an account that I previously deactivated?',
#  'What is used to create a "wet look" on silk flowers?',
#  'what is a secondery key in DBMS?',
#  'what are "distressed assets"?',
#  'how do i block certain contacts on yahoo messenger?',
#  'what are cookies?',
#  'how can i pass proxy filteration in internet?',
#  'how can i make yahoo messenger let me sign in after i have tried everything to do it?',
#  'Why do you have to add salt when you cook the oatmeal?',
#  'how can i record the ip from visitors how come my web page, and block the same people who take my pictures?',
#  'What is blended learning?',
#  'how does neon connect with atoms ?',
#  'How can I get rid of XP created up-link folder overloading memory?',
#  'what is the main difference between BTech and BE?',
#  'How come animals do not get sick consuming contaminated water?',
#  'Why do we stink when we sweat?',
#  'What is the advantage of a gas stove over an electric stove?',
#  'Why american hamburgers are so repulsive?',
#  'HOW CAN I SET MY AVATAR ON MY PROFILE?',
#  "What's the difference between salsa & picante sauce?",
#  'what are the differences between JRE and JDK ?',
#  "how can a teacher teach standard and nonstandard english while valuing a child's cultural launguage?",
#  'how do i make money quick?',
#  'how to get free money?',
#  'how do make a girl lke you?',
#  'Why is the sky blue?',
#  'how to open a college?',
#  'How to play drag race with playstation 2?',
#  'how to set up a wireless connection?',
#  'How do I get people to join my Digital Photography forum?',
#  'How I connect to la guardia community college?',
#  'what is chlymidia?',
#  "do you believe in the 'da vinci' theory?",
#  'What is PSP?',
#  'How do you know if your answers are being blocked and why?',
#  'How does a lightsaber work?',
#  'why do women become prostitutes?',
#  'why low platelet cause menorrhagia?',
#  'what is the caloric intake of an apple martini?',
#  'What is the diffrece between asprine and couted asprine?',
#  'what is broadband penetration in the U.S.?',
#  'Why when I do a Microsoft update and installs malicious tool removal does my yahoo messenger not let me log in',
#  'What is a cephalopod?',
#  'what is stem cell?',
#  'How do I clean a silk tie?',
#  'what is MSBA?',
#  "why don't we understand girls?",
#  'why is it when I try to log in to my email it says page can not be displayed?',
#  'what is the direction of surface tension on a floating drop in water?',
#  'what is plurasee and how do i treat it?',
#  'How does DVD Ripper work?',
#  'i have ADHD how can i focas in school plz help?',
#  'How does image search work?',
#  'what is biology?',
#  'What is an Emo?',
#  'how do I scald cream?',
#  'how do i know when my email has been read?',
#  'Why I have difficulty to make choices?',
#  'Which web browser is the best and why?',
#  'why do infants sleep most of the time?',
#  'why do u get stuffed up when u drink?',
#  'How can I earn 1million dollars?',
#  'Do dreams reflect how or what we feel?',
#  'What are the negative effects of low income housing on a downtown business district?',
#  'how to get coconut meat out of shell leaving shell intact?',
#  'What is the meaning of life?',
#  'how can i buy a ringtone for my cellphone?',
#  'Why do dogs and cats have red eyes in photographs?',
#  'how can i set  wallpaper to a window of an opened folder ?',
#  'Why are hispanics called a minority in California?',
#  'What does a dog look like which is a mix of german sheppard and Lab?',
#  'What are the pros and cons of learning to be a veterinary technician online?',
#  'how 2 find out if a slogen is copyrited?',
#  'Difference between java and javascript?',
#  'Why do skinny people get really bad breath?',
#  'How do I upgrade a Windows XP Home computer to a Windows XP Pro without losing information?',
#  'why do i have such a low self esteem?',
#  'what is the difference between globalism and globalization?',
#  'What is Gundam perfect grade?',
#  'How do you stop writers block?',
#  'Why do we send Christmas cards?',
#  'is dell a good computer i do not know how i feel about dell they have a good clean name but i dont?',
#  'What is the best way to cure the hiccups?',
#  'how to format a floppy disk?',
#  'why is the sky blue?',
#  'what does "pen is mightier than the sword" mean?',
#  'How do I learn english well?',
#  'What is a Metis?',
#  'is there a difference between bacterial and viral pnumonia?',
#  'how can i get my dog to sleep alone without crying?',
#  "What does it mean when a person's pubic hair has a white coating on them?",
#  'how do you animate a picture using the program paint?',
#  'how is an electron in a stable atom similar to a beta particle?',
#  'Why did the jews have numbers tattooed on them during WWII?',
#  'how do i change my yahoo i.d.email address?',
#  'Why is helium found in deposits of uranium and thorium ores?',
#  'Why Can Black People Jump Higher?',
#  'What is a stroke, and what are the risk factors?',
#  'What is the best way to learn how to correctly use the internet?',
#  'How do I transfer something from my DVR to my computer?',
#  'Why always Alice and Bob, when dealing with cryptography?',
#  'WHAT IS THE MEANING OF DORK?',
#  'why some non-christians celebrate christmas?',
#  'What AA degree is the fastest to get from a JC?',
#  'How can you measure knowledge?',
#  'How can I keep my elderly pug dog from "marking" in our new house?',
#  'Why not we have a world government for the betterment of the Humanity ?',
#  'how bad for your body is stomach acid and what problems you may have?',
#  'how can i have betayahoo mail service?',
#  'how do i hook a dvd, vcr, game cube all to a tv/?',
#  'what is the meaning of life?',
#  'why does an apple turn brown after being left for a few minutes?',
#  'Why is Starbucks Coffee so expensive?',
#  'how do i get a louder voice?',
#  'How did eyes evolve?',
#  "why won't they put dsl in rural areas?",
#  'what is the easiest and most common way to become a u.s. citizen?',
#  'why windows xp can not name a folder con?',
#  'why is paris hilton famous and why do people care about her?',
#  'how to reduce engine vibration in my car?',
#  'What is electric charge?',
#  'How a computer can be detected from where a particular e-mail was generated ?',
#  'What is degosing?',
#  'Why do elephants have tusks?',
#  'Why do people join gangs?',
#  'How did Japan develop its intellectual property so extensively after World War Two?',
#  'What do I do?',
#  'what is the importance of the 1964 civil rights act?',
#  'how to preserve fresh water?',
#  'what is rsd in medical terms?',
#  'What is LiveType Data?',
#  'what does the word billback mean?',
#  'BOO DONT ANSWER ANYMORE QUESTIONS JUST JOKEN?',
#  'how do you im people?',
#  'What is the significance of the goat in Swedish Christmas symbolism?',
#  'what are the classification of computers according to its purpose?',
#  'What is the difference between a Family Business and a Private Business?',
#  'WHY ARE CHILDREN SUFFERING IN AFRICA?',
#  'how to delete songs from ipod nano?',
#  'What are the differences of the various DVD formats?',
#  'What\'s the meaning of "life"?',
#  'Why is google charging for google-answers and why not yahoo?',
#  'how can you be brain dead ?',
#  'Why are the questions at the top of this page always the same?',
#  'what is RSVP?',
#  'how to make stretch marks disappear?',
#  'what is functional dyskinisis?',
#  'why does coffee not taste the way it smells?',
#  'how do i become a project manager?',
#  'How do I put a personal signature at the end of an out going email?',
#  'how can you separate barium sulfate from ammonium chloride?',
#  'Why do parents lie about santa?',
#  'I need to know how I can retrieve deleted emails dated from 4/05 to present?',
#  'why mostly indian guys have mousetaches?',
#  'How does one obtain peace?',
#  'how do can i use my canon a95 as a webcam?',
#  'how to stream video between DVRs in home?',
#  'Why do we say god bless you when we sneeze?',
#  'How can i speak with girls?',
#  'How should I relax from the daily work pressure?',
#  'what is the definition of vacuole?',
#  'Why is the sky blue?',
#  'how to win mega millions jackpot?',
#  'Why is it someone can ask how to kill someone....see below?',
#  'how to be succes web master?',
#  'what is Republic Act 1425?',
#  'why is water blue?',
#  'If humans evolved from primates why are primates still around?',
#  'Why was Einstein not successful in finding the perfect equation to his question?',
#  'What is Diabetes?',
#  'Why do my kneese pop when I bend them?',
#  'I am fromthe philippines,i am an english teacher how can i qualify for a teaching position in Europe?',
#  'how come dogs have cleaner mouths than humans?',
#  'Why the sea looks blue?',
#  'what is the meaning of life?',
#  'how do I make yahoo my default email for documents I create in Microsoft?',
#  'What is the measurement of the yeast in a yeast packet?',
#  'what is the Garcia law?',
#  'how do i go about getting a student visa?',
#  'What is an interpretation of the geometric mean of execution?',
#  'how r ruduce fat from my face and chin?',
#  'how do I get a job with a felony?',
#  'how to abort a pregnancy?',
#  'how do I get a grant from the government to buy a house?',
#  'how can you tell charge are flowing thought an eletric circiut?',
#  'what is y2k?',
#  'HOW DO I GET RID OF ALL THE OLD WEB SEARCHES I HAVE ON MY WEB BROWSER?',
#  'discribe how the enlightenment ideas helped foster the american revolution?',
#  'how do i become a member of the freemasons?',
#  "What's the difference between a fart and a burp?",
#  'Why does Japan not have an army?',
#  'how cold is in copenhagen in january?',
#  'How can I make the driver of Agfa cl18 digital camera work with win XP?',
#  'What is the difference between a dime and 10 cents?',
#  'How can I charge my Motorola Razr V3 with a usb cable?',
#  'How do you switch off your computer regularly?',
#  "How do you get rid of' Winfixer' on Windows XP?",
#  'how could crack on cylender block affect engine operation?',
#  'How do you delete web sites from yahoo "search the web" history drop down?',
#  'What is the difference between apple juice and apple cider?',
#  'how do i get rid of anxious stomach?',
#  'Why did Yahoo remove my awesome question?',
#  'what is meant by "salt of the earth"?',
#  'how can i become a physic and have powers?',
#  'How can I check to see if someone has autism or not?',
#  'How do I get rid of my ADHD?',
#  'what is atom?',
#  'What is the correct spelling of Hannukah, Chanukka, Hanukkah, Hanukah, Chanukah?',
#  'How do you treat/cure a hang nail?',
#  'what is a section 401(a) retirement plan?',
#  'What is the advantage of a 529 plan for college savings?',
#  "Why didn't Arnold, California's governor, not stop last night's execution?",
#  'Why do betas kill each other?',
#  'How do I get Yahoo profiles to open with norton internet security?',
#  'how can i find web of different churches?',
#  'WHAT IS 2 + 2 = ?',
#  'When you send a letter international, how does the postage get divided between the different countries?',
#  'How to grab music file from a web page?',
#  'What to do about Computer freeze up?',
#  'what is matrix?',
#  'how can I travel inexpensively solo to and in Paris March April Or Sept Oct?',
#  'what is a macrobiotic?',
#  'Why must I have an uncracked winshield in order to for my car to pass a safety inspeciton?',
#  'What does hele keliki mucka mean in hawaii?',
#  'what is thermal cutoffs?',
#  'How to install/configure Mitsumi CD burner CR-4804TE, w/out corrupting the FAT?',
#  'How can I participate in the Yahoo Mail Beta program?',
#  'how can I change IMEI code of my cellphone ?',
#  'What is an emo?',
#  'how to soften dried out lotion?',
#  'how do i fix a broken key on my ibmT41 notebook?',
#  'how to write a recommendation letter?',
#  'how do i find out the fair market value assessment of properties in wisconsin?',
#  'how do I clean out my yahoo search history auto complete?',
#  'Why is that my eyes start watering when I go out in the freezing cold?',
#  'what do you do when you have a cold?',
#  'How can people stop sweating excessively?',
#  "how do i transfer my cd's to mp3 format?",
#  'Of what use is gaining points and reaching levels?',
#  'Why is it that I can rebuild a computer,but I can barely change a tire or check the oil on a car?',
#  'What is a stinky pinky and why should I smell it?',
#  'how do you repair a seam leak in a plastic gas tank?',
#  'What is the meaning of life?',
#  "what's the definition of la kart?",
#  'What is shota?',
#  'what are the biotic factors of a deciduous forest?',
#  'Why do dogs sniff other dog’s bottoms to say hello, why don’t they just bark in their face or something?',
#  'what is the meaning by the internal magnetic field of the super conductors materials equal zero?',
#  'how can i böock a mail from someone who i donnot want to get a mail from?',
#  'what is lean logistics?',
#  'why when u sneeze they say bless you but when u coaugh thatey say nothing?',
#  'what is the origin of quantum?',
#  'How do I get my password back?',
#  'What term is correct; John rule or John rules, and why?',
#  'what is cdma?',
#  'what is the E-mail ID of Chinua Achebe ?',
#  "How to treat my friend's friend?",
#  'Why read and write?',
#  'how do i get rid of searches on the yahoo toolbar?',
#  'How can I sell an idea for a toy business?',
#  'How Do I Change my Yahoo ID?',
#  'What are the terms for Senators, Justices, and Representatives?',
#  'what does Bambocha mean?',
#  'what is the problem people have with lesibians?',
#  'How do I stop my husband from snoring?',
#  'how do know someone has had a seizure?',
#  'how does a hydrocardon make energy?',
#  'Why are the nuber of High Definition TV channels so limited and when can we all expect more?',
#  'how do planes work?',
#  'How can i use my TV screen instead of my PC monitor?',
#  'What is a STRONG PERSONALITY?',
#  "how to cash traveler's check?",
#  'What do you know about "Area 51"?',
#  'Why does there seem to be a problem because I enjoy wearing diapers?',
#  'What is wiki ?',
#  'how hot is the sun?',
#  'What is the difference between Nero Express and Nero Vision Express?',
#  'How to you clean a yellowed oil painting?',
#  'what is the history of acting?',
#  'How do I stop the Yahoo "new mail" messages from popping up and get rid of the icon in my toolbar?',
#  'Why is there an interstate on Hawaii?',
#  'How do I find the Block and lot number if I only have and address to work with for a property?',
#  'Why sexual appetite controls the mind often?',
#  'why does my throat tickle when i have this cold?',
#  'What is a line item veto and how is it used?',
#  'how can i get rid of ringworm?',
#  'How do you train a dog that is completely deaf?',
#  'How come some poeple have two different colored eyes?',
#  'Will using slanted framed glasses affect my vision?',
#  'How does the greenhouse effect work and why?',
#  'how high my blood pressure can be?',
#  'what is the meaning of B2B?',
#  'why are people more pron to suicide during the hollidays?',
#  'how can I delete the searched Items on the Yahoo?',
#  'Why do ants build anthills?',
#  "How do I renew my driver's license in Erie, PA?",
#  'Why do they still sell liquid glue?',
#  'how do i change mailbox quota limits in groupwise 6.5?',
#  'How do you say Merry Christmas in the Netherlands?',
#  'why is chapstick addictive?',
#  'How to eliminate lower back pain?',
#  'Why do so many of my questions get removed by yahoo?',
#  'how do i teach order of operations to my eighth grade students?',
#  'How do i take a screen shot while playing a movie?',
#  'why do they say cats have nine lives?',
#  'how do I get rid of a spyware that opens a IE broswer to unosearch.net?',
#  'how to erase bad credit from credit score?',
#  "Why do I forget all the questions I've ever had about life the minute I get the opportunity to ask them?",
#  'how can bond issuing be sweetened?',
#  'How can I track my pell grant check?',
#  'Why is the sky blue?',
#  "Why won't my username & password work anymore in Yahoo Mail & Messenger?",
#  'What is the perception of a Male Dental Hygienist?',
#  'How can I learn how to use chopsticks?',
#  'I need help with debt,How?',
#  'how can i determine if the person i have emailed has picked the email up?',
#  'How do you send a picture from the computer to a cell phone?',
#  'What is SLR Camera?',
#  'how to remove the words in the picture you have written in the picture?',
#  'how is the weather in california?',
#  'How do you bypass a screen saver password?',
#  'what is sufism?',
#  'what are the risks of being in the military?',
#  'how do i delete the search meau?',
#  'Do you like the new points system and new limits, why or why not?',
#  'how do you get a lot of points?',
#  'What is High Grade Dysplasia...for dummies?',
#  "Why can't we open our eyes when we sneeze?",
#  'What Is your favorite Musical and Why?',
#  'Why do we park in a driveway and drive in a parkway?',
#  "What velocity is required to escape the Earth's gravity?",
#  'Why do people say "Bless You" when someone sneezes?',
#  'What is a blog?',
#  'How can friends work through their differences?',
#  'what is a blackhole?',
#  'how harmfull is mastur_ation?',
#  "What effects would a bad distrubutor ignition module have on an engine's performance?",
#  'why dont more stores sell chanukah decorations?',
#  'Why is the sky blue?',
#  'How to enable copy/past in VNC between unix and windows?',
#  'Please i got a mail with an attachment- INVITATION and could not open to view and print out.What do i do?',
#  'why do rats not have gall bladdes?',
#  'No more points for asking questions?',
#  'how do you cook chicken in a wok?',
#  'do i have the right to ask an employer why i did not get a job?',
#  'how can i know that my computer is affected by spyware?',
#  'what is the process tochange a federal act into a federal law?',
#  'How can we build a time machine?',
#  'what is perfection ?',
#  'why Iraqi people doesnt get immigration easly to west countries?',
#  'how can a computer chip store info?',
#  'How do I find rental properties in the Whitesboro,  Sherman-Denison areas?',
#  'what is sex?',
#  'Why do Betas chew their tails?',
#  'How can I enlarge my pennis?',
#  'What is a C Print?',
#  "Im programming in c++, and when i compile an error comes back saying 'linker error: undefined reference to __'",
#  'How do blacklights work?',
#  'Why do man have butt hair?',
#  'How do i get a patton on my idea?',
#  'what is kosher?',
#  'How do I start a group home for At risk youths?',
#  'what is the difference between microsoft outlook and outlook express?',
#  'what is itamambuca?',
#  'How do you say "little" in german?',
#  'what is the meaning of PEPSI?',
#  'how to tint car windows?',
#  'why does running water freeze clear?',
#  'what is oracle?',
#  'what is the meaning of life?',
#  "what's the difference between decongestant and an expectorant?",
#  'what is geometry of sri yantra?',
#  'how can I verify that an individual is permitted to practice law?',
#  'how to use yahoo for voice chat?',
#  'What is the opinions of a boy getting his ears peirced?',
#  'How does Yahoo choose the featured question?',
#  'Are there truly reactions for every action we do?',
#  'how to improve luck?',
#  'Why are male porn stars so well endowed?',
#  'How do you draw up a professional contract without an attorney?',
#  "what's the meaning of The Public Sector?",
#  'Why are we born when we eventually have to die?',
#  'How do the stones used to build pyramids stick together?',
#  'What is the meaning of life?',
#  'What is the meaning of inherent simplicity?',
#  'why dont pepole take us blonds seruiusly anymore it not like where dumb we just have our blond moments?',
#  'What does "blood lunch" mean?',
#  'How do keymakers avoid making the same key in two different places?',
#  'how come pepper makes u sneeze?',
#  'what is faulty fetal packing?',
#  'Why are some people so nutty?',
#  'what is the disadvantange of e-bussiness?',
#  'why is the sky blue?',
#  'how to grow pot indoors?',
#  'How can I erase the history of what I have previously typed in the search box?',
#  'why do humans most easily develop a conditioned aversion to alcohol if its taste is associated with a nausea?',
#  'what is a war pig?',
#  'why does the earth rotate on a 35 degree angle and how does the moon effect the oceans?',
#  'how can you tell if a person has aids?',
#  'How do you add a picture comment on MySpace?',
#  'How can I play cable TV on a Mac?',
#  'why is my goldfish always sleeping and why does its skin reddens?',
#  'How is defference between notebook and laptop?',
#  'how is santa claus symbolic of christmas?',
#  'How come no answer area about legal questions ?',
#  'What is the abstract concept of temporal paradoxes?',
#  'how to controll diabeties?',
#  'how to download my window to window xp ,,i have dell laptop it has window98?',
#  'How can I get a  Visa to enter saudi arabia as a non european person?',
#  'Why is the sky blue?',
#  'HOW DO I GET RELEIF FROM MY ARTHRITUS PAIN IN MY HANDS?',
#  'what is the universe for?',
#  "Why do ice storms knock out some people's power?",
#  'what can i do or how can i delete a contact that is verbaly harassing me and my family on my yahoo messenger?',
#  'Why does the government want to change the name of christmas to just holiday?',
#  'Why do those new Army fatigues have a kind of "digital" pixellation look?',
#  'What is the difference between an alcoholic and a binge drinker?',
#  'how do you retrieve message waiting from vonage phone?',
#  'How to treat erectile dysfunction and premature ejaculation due to Bipolar disorder and its medicines ?',
#  "What is Charlie Brown's complaint about Christmas?",
#  'why is it that in some parts of the globe, jews are generally discriminated?',
#  'How thick is the RAZR from motorola?',
#  'how is energy packaged?',
#  'Why do we need the patriot act, seriously?',
#  'what is meant by Single Malt whisky?',
#  'How do you get a job at 13?',
#  'why does the American military have secret prisons?',
#  'what is a dc converter?',
#  'How to stop unwanted behavior and still keep friendship?',
#  'What is penetration testing?',
#  'What causes homosexuality?',
#  'how to hide my ip from hacker?',
#  'What is a Crip and what is a Salvatrucha?',
#  'how do i send my list to someone on yahoo messenger?',
#  'how do i add someone to my instant messenger?',
#  'why are we warm blooded?',
#  'How do I get rid of pop upblockers?',
#  'how does google make money?',
#  'What exercises can I do while I am recuperating from ankle surgery?',
#  'How are Navy Wives stereotyped in society?',
#  'what purpose does snot serve?',
#  'why is lumber a porfitalbe commodity?',
#  'Why do people keep typing their questions in ALL CAPS?',
#  'how can i succeed in my life and study ?',
#  'Why did The Media dislike Howard Dean?',
#  'What is a sophist?',
#  'why do the acetaldehyde, acetone and cyclohexanone exist in the keto form instead of the enol form?',
#  'How can I listen to mp3s from my Treo 650 through my car’s audio system?',
#  'what is multymedia?',
#  'What is the difference between a student loan and a grant?',
#  'Why is the future so shiny?',
#  'How do you get grease stains out of clothes?',
#  'how do you change the brake light on a 1995 chevy cavalier?',
#  'why does my head ache?',
#  'how do senior secured notes work?',
#  '"Why do teens run from there problems, instead of getting help"?',
#  'Why did you get out of bed today?',
#  'What is the meaning of an entity?',
#  'how can i tell if person i emailed has opened it ?',
#  'why are brothers such pains in the buts?',
#  'what is the model of 2-door/2-passenger Volvo?',
#  'how do I save program data to drive D?',
#  'What effects does peniclillin vk have in MARIJUANA URINATION DRUG SCREEN TEST?',
#  'what is the meaning of life?',
#  'how do i find out if my income tax refund will be taken by the irs?',
#  'how can i boot someone out of a chat room?',
#  'ps2 to pc how to copy?',
#  'How do I go about getting my business license?',
#  'What is the meaning of life?',
#  "Why can't you map a 3-D object into 1-D?",
#  'What I can do when my computer could not detect the CDROM & CDWriter?',
#  'How do you win the lottery?',
#  "What's your fav Italian place in Palo Alto area and why?",
#  'what are blogs ?',
#  'how can I remove trojan.download.ruins from my computer?',
#  'how could I pass an exame without study?',
#  'What is the difference between an Attorney and a Lawyer?',
#  'how do u get free songs for ur ipod?',
#  'how can i play online chess?',
#  'what is spirituality realy?',
#  'Why yahoo answers ak for login again?',
#  'How did K-rail barriers get their name?',
#  'how does the presence of hydrogen bonds affect the boiling point of a substance?',
#  'Why do you like/dislike "tabindex"?',
#  'How do you make chocolate covered raisins, without a flat spot?',
#  'what is the relation of artificial intelligence to game development?',
#  'how can ihave back my yahoo mail with out BETA?',
#  'What causes black stools in humans?',
#  'what is the mearning of buzz?',
#  'why is the sky white and blue?',
#  'Why does the body tend reject organ transplants but not blood transfusions when blood type is matched?',
#  'Why the guilt the  day after  got drunk?',
#  'what is the user account asp.net?',
#  'What is the difference between thinking and feeling?',
#  'what is the "black pope"?',
#  'how can i put an icon in icon tray(ie beside system date but not in Quick Launch) in xp?',
#  'we have to return computer, how do i delete my friends list i dont understand your procedure?',
#  'What are some famous eats in NYC?',
#  'what is mean by tsunami?',
#  'Why is the North Star always in the north, yet the other stars move?',
#  'What is a quark?',
#  'What is a spoort hernia?',
#  'what is lean manufacturing?',
#  'How do tell a friend to stop bragging about her clothes and stuff, and yet not hurt her feelings?',
#  'What is an futures contract?',
#  "What's the difference between setup and install?",
#  'what is parkinesonism?',
#  'why do I get a page can not be displayed message when I try to sign on to yahoo mail?',
#  'Can someone advise on how to send photos through outlook express?',
#  'Why do men have nipples?',
#  'why do my employees not understand the concept of showing up on time?',
#  'what is tresadecaphobia?',
#  'Why are you afraid to start your own business?',
#  'why are americans so fat?',
#  'if you need airplane ticket and dont have the cash-what do you do?',
#  'How Great is Yahoo Answers?',
#  'Why do people say (god bless you when you sneeze) ?',
#  "What exactly is a baker's dozen supposed to refer to, 13 what?",
#  'how do I delete past searches from the yahoo search toolbar?',
#  'How can I tell if my cat is bulimic?',
#  'How can I be more assertive without feeling like a mean person?',
#  "What does _('foo') mean in PHP?",
#  'HOW CAN I ERASE THE HISTORY OF THINGS I HAVE LOOKED UP?',
#  'how does a jet moter work?',
#  "what's the cheapest way and time to fly from DC to Thiland?",
#  'how do i subscribe to dish network?',
#  'When i try to open mozila firefox it wont open what do i do?',
#  ...]

# %%
dataset['answer']
# Out:
# ["A small group of politicians believed strongly that the fact that Saddam Hussien remained in power after the first Gulf War was a signal of weakness to the rest of the world, one that invited attacks and terrorism. Shortly after taking power with George Bush in 2000 and after the attack on 9/11, they were able to use the terrorist attacks to justify war with Iraq on this basis and exaggerated threats of the development of weapons of mass destruction. The military strength of the U.S. and the brutality of Saddam's regime led them to imagine that the military and political victory would be relatively easy.",
#  'Call an area apiarist.  They should be able to help you and would most likely remove them at no charge in exchange for the hive.  The bees have value and they now belong to you.',
#  "There's a general belief in Europe (and in fact elsewhere in the world, such as China) that it's unhealthy to drink water with a meal because it dilutes the digestive juices. Wine is OK because it stimulates digestion, and mineral waters are also considered digestives.. . In general, Europeans are much more concerned with the digestive process than Americans.",
#  "hybrid cars save energy in two ways: 1.by storing energy from the breaks2.by engaging the gas motor only in it's most effective work RPM meaning that the system will engage the gas motor mostly at coursing speed (close to the most efficient motor RPM)Having said the above, driving in the city almost never gets you to the efficient RPM.Also- it is true that the same energy that is being stored in the cars' battery needed to be generated by chemic energy. The cool thing about it is that the pollution can be outside of the city and not in the city. (Like in San Francisco, the electric buses generate the same pollution as a gas buses it is just not in the city.You can also add that electric engines are much quieter then gas engines.So- all in all- I the hybrid benefits are more visible in city driving",
#  'In general it means that in a very high speed (also apply for low speed but hard to measure) , a Mass turns into Energy and vise versa. The conversion rate is C2 (C square).',
#  "I used to work in a college admissions office for a major university and they used a specific formula for calculating GPAs. They did this to put everyone on an even playing field - so that high schools that don't weight AP classes differently would be measured the same as those that do. Though I don't remember the specific calculation anymore, I definitely remember that AP classes were given a higher score. I'd suggest you take the AP class and try for the best grade you can get - because ultimately it'll be weighted higher at the college/university you are interested in, giving you a better chance of getting in!",
#  "I don't have an article, but I was listening to NPR last night, and the commentator was saying the evacuation was really bungled due to an organization and communication problem. No one took charge and said, hey I'm running the show, get 2000 buses and send them down, because no one felt they were in charge. FEMA, State & local police, National Guard, all were not sure what the other guys were doing and so waited for overall direction, which never really came.",
#  'There make very low frequency sounds that we cannot hear. They also make sounds that we do hear and it is because they what other animals to hear it.',
#  'its expected, as the concentration of the molecules that have the scent they are trying to get rapidly fades away with distance. . . They can get a sense that something is there, but when they are very close, probably they will have even more information: how long that smell is there, how many different scents are there, etc.',
#  'Fill a large pot with 1/4 full of water or just enough to cover your lobster and add a generous handful of salt. When it comes to a boil, put the lobster in the pot head first. Then boil for 18 for the first pound and 10 minutes more for each additional pound.  For lobsters over 7 pounds, 8 minutes per additional pound is enough.',
#  'There are two kinds of primary colors:  those you get by combining light (these are called "additive") and those you get by mixing pigments (these are called "subtractive").  As many computer users know, the additive colors are red, green, and blue.  Traditionally, the subtractive colors were red, yellow, and blue.  But more technically, they are magenta, yellow, and cyan (a kind of blue).',
#  "Knock on the watermelon (just like you would knock on a door).  If it sounds hollow, it's ripe.",
#  'Tougher cuts or meat with more fat. These cuts will stay juicy and become tender from the long, slow cooking time. Pork loin is not the best choice for slow cookers.',
#  'Possibly because African royalty used umbrellas as protection from the sun, and opening one in the shade was considered an insult to the sun god. Opening it indoors was also taboo.',
#  'Bubble tea is a drink that is a mix of tea, milk, sugar, and giant black tapioca balls. The "bubble" refers to the foam created by shaking the freshly brewed tea with ice.  It is also called boba tea, tapioca tea, boba nai cha, pearl tea, milk tea, bubble drink, zhen zhu nai cha, tapioca pearl drink, momi, momi milk tea, QQ, etc.',
#  "Eggnog is a popular wintertime drink.  We do not serve eggnog only during Christmas.  It is also popular on New Year's day and some serve it on Thanksgiving.",
#  "European butter has a higher percentage of butterfat.  That's why they smell so yummy, e.g. plugras.",
#  "In most cases, the television needs to 'warm-up' its cathode ray tube before it can start to display an image on the screen.. . The audio coils require much less charging time and can start to emit sound sooner than we can see the image on the television.",
#  "resume writing can be tricky because not only is it important to be detailed when describing skills and work experience, but it is also advantageous to balance this with brevity. be concise and to the point while packing your resume full of key information that presents your strengths as a candidate for employment.. keep it simple, and make sure that formatting doesn't take away from a neatly streamlined and cogent resume.. below is a link to hotjobs' resume tips, which i found extremely helpful in this process.",
#  "I believe it originated in Croatia sometime in the middle ages where it was primarily worn by men to show allegiance to their King. It seems to have gained popularity in France where the French form for Croatia resulted in them being called 'cravat'. Details in the article.",
#  "China is more concerned with threat from US or Japan than North Korea.  Besides, both India and Pakistan have nuclear weapon already and are close to China as well.  But it's hardly a big concern for China people.",
#  'Presumably because they tend to be longer/bigger to accommodate extra space, and the most efficient place to put a larger stall is at the end of the room. (It would be in the way if it were in the middle.)',
#  'The Pontiac Aztek.  Cars like the Scion xB and Toyota Prius are polarizing cars but they sell in big numbers and hit their targets.  The Aztek was frighteningly faithful to its concept vehicle and answered a question that no one asked: what would happen if we put a sloping rear window and regular doors on a minivan?  Heads should have rolled at GM for that decision, the sales for the Aztek have been abysmal since its launch.',
#  'Salt is traditionally added to the rim of the glass to provide a sharp contrast in flavor to better experience the drink as a whole.. The difference in the salt and the sugar content in the alcohol helps to stimulate all of your tastebuds, which are divided into sectors based on the type of sensation.. Take caution to not over-salt the rim of the glass and thus coat only the outside portion of the rim around 1/4"... getting salt on the inside of the glass risks modifying the flavor of the drink.',
#  'Common Gateway Interface (CGI) is an important World Wide Web technology that enables a client web browser to request data from a program executed on the Web server. CGI specifies a standard for passing data between the client and the program.. . An aim of CGI is to be language-neutral, though Perl is often associated with it.',
#  'I suggest going back to your computer for FPS. Console controls are not well-suited to FPS style gameplay. The only console that will truly be able to pull this off well is the Nintendo Revolution (which will come out next year).',
#  'Blueberries are high in anti-oxidants. Also, they are low in saturated fat, cholesterol and sodium. They are a good source of dietary fiber, vitamins C and K and manganese.',
#  "Parkway doesn't refer to parking a car, it refers to the greenery or parkland landscape next to the road.. . The driveway isn't necessarily meant for parking a car, though many people do. It is the path you drive up to get to the house.",
#  'Dating from the 1920\'s the expression buck naked commonly means completely or totally naked or without a "stitch" (as opposed to partially naked). Synonyms include "bare naked", "buck-arse naked", and "butt naked" (also spelled, facetiously, "butt nekkid"). In the South, "buck naked" or "butt naked" means not in your house, out looking for trouble on Saturday night and wearing no clothes.',
#  'Well, from wich perspective do you look at it? In my opinion, physical reality incarnations are done for the purpouse of spiritual growth..."body is a car, soul is a driver, YOU". Aside from that, I believe all is devine, in other words, all is god, source, as some say it. I also believe that each seek\'s to reunite with source... :) Take Care, Love and Light',
#  'Simple math: one hand on cell phone, other hand on coffee mug, right foot on gas pedal, left knee for steering.  What do you want them to use to activate the turn signal?',
#  "Premenstrual syndrome (PMS) is a group of symptoms related to the menstrual cycle. PMS is linked to changes in the endocrine system, which produces hormones that control the menstrual cycle. Medical experts don't fully understand the chain of events that causes premenstrual symptoms to be severe in some women and not in others. The one direct cause that is known to affect some women is genetic: Many women with PMS have a close family member with a history of PMS.",
#  "Don't panic, sometimes they'll tuck you in at the last minute.  Also, if you really need to get into that particular university, you need to wait it out.  Or you can attempt to dig out some additional proof of how wonderful you are and beg/cajole to re-apply.  No matter what happens, ensure you have at least another university to fall back on.",
#  'Because Firefox and IE comprise the majority of the browser market by far.  Safari support is in the works.',
#  'President Nixon\'s secretary, Rose Mary Woods, said she may have erased several minutes of the tapes when she "accidentally" pressed record while answering the phone.  There\'s a famous picture of her showing how this might have happened (included in link below), but the picture actually makes it look even more unlikely that it was an accident.. . Most people believe that the tapes were erased intentionally, either by Woods or someone else.  No one knows what\'s on them.',
#  'I recommend tables of conversion factors or units.  An example is one provided by Wikipedia for free.',
#  "I recently backed up and restored a bunch of files using Roxio's Backup MyPC Deluxe, which was bundled with my copy of Easy Media Creator 7.5.  I don't know how secure the encryption is, but it definitely lets you recover files to any computer.  I would assume that any of the more recognized packages (i.e. Norton/Dantz Retrospect/Ghost) would let you restore files to a different machine as this seems to be a core feature of a backup program.",
#  "There are 100's of strains of the virus that causes the common cold, and each one is constantly mutating, and so finding a cure is like a 100 moving targets, all going in a different direction.  But yes, maybe it is a conspiracy of the big drug companies, just like the CIA caused AIDS :)",
#  "one can argue that in order to become an answerer you first need to be an asker- how would you gather a more then common knowledge information- you need to inquire, thus ask many questions. only then you can answer other's people questions.. . So- He who wants to become an answerer must first be an asker",
#  'I am using Firefox, because it has tabbed browsing, tighter security, many useful extensions, and .. I like  the fox symbol.',
#  'I actually didn\'t deal with wireless networks b4. but in the control panel u will find a "Wireless Network Setup Wizard". It is a wizard that should manage to configure it for u. . I\'m assuming u have Windows Xp SP2',
#  "It appears that the question period has expired. If you have received an answer that meets your needs, please choose a 'best answer.'. Regards.",
#  'I agree with the previous two answers...go see a dentist/hygienist, get a professional cleaning, and ask for instruction on how to floss correctly.  It may help prevent gum disease, and allow you to keep your teeth for a lifetime!  (which is how long healthy teeth last!)',
#  'what do you mean by save movies? where are you getting them from',
#  'First - education helps. Second, experience. Third, and some would argue most importantly, knowing people who are in positions to get you a job.',
#  'Stop using IE and get Firefox 1.5 with the google toolbar.  That will nix most pop ups altogether. Or use Google toolbar with IE and enable the pop-up blocker.',
#  'A simple answer is hate.  By nature we hate things for various reasons, so terrorism is just acts of strong hate.',
#  '"not able to run" ??   What happens when you click the shortcut - absolutely nothing, OR does it appear to start to open, then vanish almost immediately (OR something quite different) ??',
#  "A cloud compsition is primarlly just billions of drops of water or ice.  When such a cloud formation has an influx of water/ice, ie it's mass increases to include more water/ice, light finds it hard to pass through the mass, thus making it darker for us to see.. . In a normal cloud, light can pass through the water/ice within the cloud and we see it as a distorted white/bluish/greyish/greenish hue.  But when the cloud is too thick with water/ice, the light doesn't pass through so easily and we see a darker spectrum.",
#  'There are other solid propellants that are more stable and efficient e.g. ammonium perchlorate NH4ClO4. Chemically speaking, calcium carbide is commonly used when welding metal in the form of acetylene...its tank technically being a "fuel cell."',
#  "That depends on what L and P are.  If you plug the permitter and length in, you can get width W.. . If you want a formula that will yield W, it's: (P-2L)/2 = W",
#  "Learn well the fundamentals of Computer Science.  Hardware may constantly change (Moore's Law) but the underlying theories will last forever.  Good luck.",
#  "It was originally added as a way to 'stretch' the coffee,which was very expensive. Eventually people became accustomed to the taste and began to prefer it. It is now added as a flavoring. It is most often associated with the city of New Orleans and beignets.",
#  'citizens are went to election centers and select the prefered list of candidate . electronic election is not used',
#  'according to a repair article on the popular mechanics site..... a regular sheet of 1/2" weighs a bit more than 54 lbs.  i know that green board (moisture resistant) is heavier.',
#  'A protocol would be a standard procedure or practice that is in place...usually in a work place but can apply to alot of things. It just basically says if this happens then we should do...steps 1 2 and 3.',
#  "For PDF to Word conversion, I've found that SolidPDF does a good job.  It does a very good job of preserving formatting - not perfect, but very good.",
#  'good student discount. Some give discounts for safety courses.',
#  'Yes.. It is not a thing I believe, it is a thing I experienced, it is about seeing.',
#  'scoop-like utinsil that is used to scoop the meat of fruit in ball shapes.. . See link below for an image.',
#  'tools, internet options, clear history, delete cookies, delete files, then go to the content tab, click autocomplete and uncheck the boxes there.. . and while you have the internet options open you can go back to the first tab and click clear history, delete cookies and delete temporary files.',
#  'if the baby comes out feet first, I runs the risk of have the cord wrapped around the neck,and can choke it to death. If the baby comes out head first, doctor can make sure the cord is not wrapped around the neck. Also the head and shoulders need to come out first as to allow the vagina to stretch enough to allow them to slide out.',
#  "Most of the camera works exactly the same as any other... there's a lens that focuses and a shutter that is normally closed, blocking light from passing through the camera, but opens when you want to take a picture. In a film camera, the light that gets through the shutter while it is open hits film, which is chemically sensitive to light. Digital cameras use a charged-couple device instead. This is a photosensitive (sensitive to light) computer chip, which converts the light energy into information that can be read by a computer.",
#  'After you log in to your account, click on the "Options" link on the main page in the upper righthand corner. From there, you will find links to all of your Yahoo Mail settings.',
#  'usinng a USB 2.0 cable to connect a PSP to a computer wont work. There are computers that come with the 3 plugs(red,yellow,white). If your computer does not have that, there are special decices that do that. Not plain cables, and they can cost a lot.',
#  'Your son was made truly special by God. It can be difficult for you acceptin that he is homosexual, but remember that he needs to feel that you still love him, because of whom he is, his sexual orientations, doesnt change the bone that connects you both. If you are having problems acceptin his homosexuality it would be good if you talk with an specialist (psychologist) or join a group of parents with gay children. Any of them could help you come closer and understand more the feelings of your son.',
#  "Lots of work, but don't count on lot's of clients, as you know, jobs are going over seas, leaving only retail and service workers in the state, who have no insurance, therefore, cannot afford your services. isnt trickle down economics great!!!!!!!!!!",
#  "Sounds like the dog is poorly trained.  If it's anything like my dog, it wants to come inside to be with people, but when it gets near people it can't control its excitement.  My dog also whines because she wants a cookie.  Next time you go over, bring the dog a giant chew bone, something that will keep it busy for hours.",
#  'This is not something you can see with Yahoo mail.  Both the sender and receiver must have an e-mail program (such as Outlook) to utilize return receipt.',
#  "Israel will launch an attack on Iran only if it feels that it is the only way to prevent an attack. I could see Israel bombing a vehicle that was to supply enriched Uranium if they felt that bombing this vehicle would delay Iran's Nuclear plans by some significant aount of time.. . Note that when Israel launched an attack in Iraq's Nuclear plant (condemned by the world at the time) they made sure to do so when they knew there would be minimal casualties on the ground.",
#  '1 The cost to mine it is getting more expensive.(FUEL & Labor and repair parts.2 The value of a dollar versus other curency is lower(compared to some other Countrys currancy rate).3 Gold is being bought as investments.So gold will hold more of its value compared to a dollar.',
#  "If both parties have the internet then MSN messenger has a Voice Chat function, as do many Instant Message programs. If you are not a fan of IM's, try Ventrillo or Teamspeak.. . Skype has already been mentioned.. . You can purchase telephone handsets for your PC if a headset/mic combo is not suitable.",
#  'Well Blog is read. And Podcast is listened. Blog files are html (or php/asp/other web language-generated HTML) files. Meanwhile Podcast files are mp3s, which you can download to your iPod or other mp3 players.',
#  'Integrating SSL layer with IIS is just installing the security software from  the vendor and installing the digital certificate. You need to open the port 483 also to enable the HTTPs connection.',
#  'I don\'t know if I\'d call it a "hero", but it is a useful way to provide metadata for a site in a way that browsers can understand.  For example, Slashdot uses it to link to authors of articles, parents of articles, yesterday\'s news, etc.. . Unfortunately, most browsers don\'t do anything with most <link/> elements (with the exception of stylesheets), so we\'ll have to wait and see what people really do with them when people can use them.',
#  "Those who do this have no respect for other's religion or personal property. It's just the world we live in...sad to say.",
#  'that would be a really neat twist to things but i think his fear will win in the end.  draco fears voldemort more than he listens to his conscience.',
#  'right now in chennai its pouring!! with an extreme monsoon this season with almost 3 cyclones hitting the costal city, the city is drenched :)',
#  'Go to the Gift Registry Kiosk by the Jewelry Department. A Jewelry Associate can assist you if you need help. If you are approved, you will get a shopping pass that you can use that day.',
#  "you may forward it manually to the other account. For some, there'll be an option to forward all incoming mails to a different address. If you're using the free yahoo account, you wont get this option.",
#  'depending on the service provider offer, some companies offer the service of locking your stolen phone by preventing the specific (IMEI; International Mobile Equipment Idendity) from accessing the network. they have (EIR) Equipment idendity register they just have to delet that your IMEI number from the database register, but also i have to tell that there are many programs used now to unlock those closed phones. in addation there must be some integration between the Police and all mobile companies to have a complete shared database for the stolen phones. in that case the phone will not be used inside the whole country also it can be traced to catch the stealer.',
#  'perhaps you mean lagniappe?  if so it means a small bonus or gift...',
#  "did you try the soft reset or the hard reset? the hard reset might restore the factory settings, which MIGHT unlock your ipod. i'm not even sure theres a way to reset an ipod, now that i think about it. did you contact Apple?",
#  'Sauce is a very generic term referring to any semi-liquid condiment that is used to add flavor to food.. . Ketchup (or catsup) is a specific type of sauce that consists of tomato puree, vinegar, sweetener and spices, with the tomato being the dominant flavor.',
#  'the only way 2 make yourself invisible is to use your stealth settings. to do so, just click on your status message and choose invisible to everyone. wen your done, just go back 2 being available',
#  'Want an answer a bit more technical?. . Perfume has 15% to 30% of perfume oils.. Eau de cologne has 3% to 5% of perfume oils.. In between are eau de toilette (4-8), and eau de parfum (15-18).',
#  "When Social Security was started in the 1940's, it became to unweildy to try to administer it based upon the recipient's name (lots of John Smith's in the U.S.A.).  As such, a 9-digit number system was developed.  Numbers are assigned according to geographic birth location, and date.  Since it was a national system, and just about every citizen was required to have an SSN, it grew to be used as a national tracking system by both government and commercial entities.",
#  'To connect one PC other..U can easy to transfer data one pc to another pc.In N/W there are 3 types . # LAN(Local Area Network) Communications network that serves users within a confined geographical area. It is made up of servers, workstations, a network operating system and a communications link.. 2)# MAN(Metropolitan Area Network) Communications network that covers a geographic area such as a city or suburb.. 3)WAN(Wide Area Network) Communications network that covers wide geographic areas, such as states and countries.',
#  'What kind of "weird noises" is your dove making? It\'s impossible to answer this question without more information.',
#  'Trillian is a fully featured, stand-alone, skinnable chat client that supports AIM, ICQ, MSN, Yahoo Messenger, and IRC. It provides capabilities not possible with original network clients, while supporting standard features such as audio chat, file transfers, group chats, chat rooms, buddy icons, multiple simultaneous connections to the same network, server-side contact importing, typing notification, direct connection (AIM), proxy support, encrypted messaging (AIM/ICQ), SMS support, and privacy settings.',
#  "I think sometimes it's hard to express our feelings openly, but we feel more comfortable expressing them in a note or letter.  Sometimes I prefer to write a letter because it gives me time to think about exactly what I want to say.  Also, it's fun when you know who wrote the letter and they don't!",
#  'The Internet, or simply the Net (and often erroneously synonymous with World Wide Web), is the publicly accessible worldwide system of interconnected computer networks that transmit data by packet switching using a standardized Internet Protocol (IP) and many other protocols. It is made up of thousands of smaller commercial, academic, domestic and government networks. It carries various information and services, such as electronic mail, online chat, and the interlinked web pages and other documents of the World Wide Web.',
#  'This is a very good question, my guess is that your cat sees you eating something, and he figures that if its good for you, it must good for him too. Both of my cats are the same way, what I eat, they eat.I used to have another cat named spookers,he loved stewed tomatoes and all sorts of vegies.',
#  "Average out of college bio/life science job starts at around USD 30K. Assuming you have three years of experience, and if you were working for the company, you'd receive a 5% raise each year for the job well done, you're looking at $35K as target range.",
#  'Nutrition (depends on certain soils: mixed compost, clay-like dirt, moss, bark etc.), Sunlight or other warmth, Air, Water, and depth of how far the seeds or roots are planted into the soil. Different plants require different depths when being planted.',
#  'Well, the best way to tell is to invite him to lunch one day and take him out and make good friends of him and eventually he might forgive and forget the mistake.. . If you dont like this then you could talk to him about it when ever you get to personally meet him.. . You could also email him saying that You did not mean exactly what went wrong, but yet making him understand that you are equal to all employess. End the email with, I have lots of confidence on the other projects he was doing and that you did not want to put pressure on him with more of the projects.',
#  '100000 all the way! Jesse McCartney is SOOOOOOOOOOOOOOO hot!!!!!!!!!!!!!!!!!!!',
#  "there is a'Call a Poll' option on your page, just below your question when you recieve more than one answer. Click that choice",
#  'This can not be done due to sanitation laws. There has been no inspection of your brewing facility. Also the liability issue is huge if you make some one sick. Many home brew clubs share beers , but this is doen afterhouras at a bar or at a persons house.',
#  "Professional clean only!  You could try spot cleaning but to get it clean, you will have to have a professional do it!. That's just the way it is....sorry!",
#  'RUP stablishes a series of steps that need to be completed for the succesful completion of a project. Assign resources to every one of these stages and milestones to track the project.',
#  'he gets double dog dared to stick his tounge on the flag pole and he dose. he ends up getting his tounge stuck to the flag pole and is pried off by the fire department needless to say ralfy gets blamed for it',
#  'monkey-see monkey-do. Dr. Steven M. Platek has said that we yawn b/c we are unconciously imitating other humans. (probably some kind of evolution thing) I guess there are many other species that yawn...fish, cats...(i would totally pay to see a fish yawn!).. By the way although it used to be believed that it was to get more oxygen, this, however, is not true.',
#  'Just like it says, the page cannot be displayed. It can happen for various reasons such as the page is no longer there or the site is just down for the moment. You can try refreshing the page to see if it will come back up or try again later.',
#  'Wel there are public directories around from where you can find the address of any friend. For this you can put his name is any search engine like yahoo and more. Its possible that it will lead you to answer youa re looking for. But please use it only for good reasons.',
#  "3 sunny side ups every morning does it for me.  I use a smiggin' of cooking spray in a non-stick pan (i know that seems redundant), and I slide the eggs out of the pan and onto my plate.  YES!!!",
#  "If you've built up static charge on yourself and want to get rid of it, then you need to safely discharge it in a way that doesn't hurt. The best way is to touch a non-sensitive part of your body (like a knuckle) to something that's grounded (like a water faucet).. . More info on static electricity is available at the links below.",
#  'Run a Stereo Patch Cable (avail. at Radio Shack) 1/8" mini TRS to RCA right and left.  1/8" mini plug will go into your headphone jack on puter, the other end, red plug & white plug will go into aux. input on your stereo.',
#  'There is no known physical effects. However; there is thought to be some chemicals that are released from the brain(endorphines) I think which is a chemical that causes one to be in a more positive mood.However; if one has been sexually active and then is not( do to breaking up with partner/ can\'t "get any") one may experience the "sexual tension" although does not cause "harm" can makes ones temperment short.(ie. cranky)lol',
#  'I\'ve never heard of that Tradition.  However, Daegan is a gaelic name for males meaning "dark-haired".',
#  '"Since 533, the new Pope has also decided on the name by which he is to be called at this time. Pope John II was the first to adopt a new papal name; he felt that his original name, Mercurius, was inappropriate, as it was also the name of a Roman god. In most cases, even if such considerations are absent, Popes tend to choose new papal names; the last Pope to reign under his baptismal name was Pope Marcellus II (1555)."',
#  'Just scan the file for viruses after you download it.  A general rule of thumb is don\'t download something like a "bios" update from a hacking site or anything that looks like it "might" not be legit.  Check the size of the file versus the size of the same file posted on other sites.',
#  'They go into elementary education because they like kids.. . Partly it is because there are more elementary/kindergarten teachers employed in schools than any other type of teacher so the job market is larger.',
#  'Some of the obvious benefits are expense but, some are for example you can get a not so used vehicle for alot cheaper than you would a new one cause who ever bought it new has already to the hit on depreciation and you can benefit from this!  The best example of this is a Used Toyota--new its price is signicantly higher than a used one of the same model year with less than 10,000 miles cause they do not hold their value as well as they did once before.  My suggestion stick with Japanese engines-Honda, Toyota, Subaru, Nissan,(in that order) I hope this helps if you have any more questions feel free chrystal_luvscars@yahoo',
#  'You can press shift+delete (in Firefox) or ctrl+delete (in IE) to delete an indivudal search. If you\'re talking about the Yahoo Toolbar, there should be a "clear history" option at the bottom of the history list.',
#  'Oseltamivir is an antiviral drug, a neuraminidase inhibitor used in the treatment and prophylaxis of both influenza A and influenza B. Oseltamivir was the first orally active neuraminidase inhibitor commercially developed. It was developed by Gilead Sciences (Donald Rumsfeld is a major stockholder of Gilead Sciences) and is currently marketed by Hoffman-La Roche (Roche) under the trade name Tamiflu®.',
#  "You can also use the &#92;hline command.  I've linked to documentation about that command as well as a good LaTeX reference.",
#  "It's not that finger, it's the hand gesture.  And it's considered an obscene gesture because it is meant to represent male genitalia.  Nor is it universal.  Other countries use hand gestures that we consider innocuous as vulgar gestures.",
#  "I have used alcohol on q-tips. You can always give it a shot and if that doesn't work, then you can take your kitty to the vet.",
#  'Go to "page set up". Click on the "sheet" tab.  There is a section that is tilted "Print". Click on the option that says "gridlines".',
#  'Use filters if u r usin yahoo. i believe other companies also provide this facility.',
#  "If you want something blue just add food coloring but I wouldn't do that often because it may be harmful. It is meant for food not drinks.",
#  'The rule of thumb is likely derived from the fact that people used the thumb as a measuring device. The length from the tip to the first knuckle is roughly an inch and perhaps the length of the inch is derived from this fact.',
#  "It appears that the question period has expired. If you have received an answer that meets your needs, please choose a 'best answer.'. Regards.",
#  'turn off the computer.  spray some windex on a clean cotton cloth (not a paper towel), then GENTLY wipe the screen with the cloth.',
#  'assuming this is a joke question.. here, this may help. abcdefghijklmnopqrstuvwxyz',
#  'Try somre contact lense rewetting drops. They tend to add more moisture to the eye than a regular eye drop.',
#  "That's your body telling you that cigarette smoke is bad.  Tell people not to smoke around you.",
#  'It depends on the browser and what program changed it but you should be able to chang it back by going in IE to Tools > Internet Options > General and type in the homepage you want to use.  In Firefox go to Tools > Options > General and enter the homepage you want to use.. . The answer by tsq will work for IE (or your default browser) but will not change it for others.',
#  'ID3 is a tagging format for MP3s. It allows metadata such as the title, artist, album, track number, etc., to be added to the MP3 file.',
#  "With no quick starts or stops, take is slowly.  Best if you have a front wheel drive vehicle.  If you start to slide, steer in the direction your car is sliding, tap the brakes, don't panic.  Keep a good distance between you and the next vehicle.",
#  'Bad power supply probably, It can be replaced.. . Hard to tell for sure without examining it.',
#  'Here is a link to an old Mother Earth news project where they run a pick-up truck with wood and no engine mods! The process, wood gasification in a pre-burner could probably be adapted to garbage, too.... (Vegetable-oil-conversion involves a diesel engine)',
#  'Any amendment proposed and passed by the US Congress must be ratified the the state legislatures of two-thirds of the states.  Individual states cannot, however, make direct changes to the constitution.',
#  'First do a compression test and make sure your engine is in good condition to accept the additional cylinder pressure.. . Then come up with a horsepower goal which will dictate what size turbo in cfm you want. Bigger turbos have more peak output, but smaller turbos spool faster and have a more pleasant power curve.. . If you run the turbo at more than 8 psi or so, you will also need intercooling.',
#  'Yahoo Answers is solely dedicated to asking and answering questions.  If you read the community guidelines they strickly prohibit asking questions in an attempt to chat or have discussions with other members.',
#  'Dell\'s printers are manufactured by Lexmark, but they do something slightly differently, so you cannot use Lexmark cartridges with them. Your best bet would be to get an inkjet refill kit, which allows you to fill the cartridge or a remanufactured cartridge, which you can readily find by searching for "inkjet refill" on Google.',
#  'There is a computer that can tell, for each wheel, the speed the wheel is spinning, and also the rate at which the wheel is decellerating.  The computer also controls a set of valves that regulate the brake fluid pressure to each tire.  When the brakes are engaged, the computer monitors the wheels, and if any wheel begins to lock up, the computer releases the brakes on that wheel a little, until it speeds back up slightly, and the process repeats until all four wheels have stopped.',
#  'Causality prevents information from traveling "backward" in time, and is the most sacred tenant in physics.  Relativistic time-dialiation (above) is certainly interesting, but there is no time-travel theory (quantum or otherwise) that won\'t be met with anything but snide remarks by a real physicist.',
#  'At one time Britishers were ruling maximum contries in the world and it was said that "Sun never sets in Queens rule". In India also there is a saying Angrej chale gaye, Angreji Chhod gaye" Englishman are gone but English is still here.',
#  "One way to open a geode -- to reveal the crystals -- is with a chisel and hammer. Score the geode completely around the outside where you want it to crack -- usually in two equal halves. Keep going until it cracks and breaks apart. This will almost always work and won't damage the crystals.",
#  'Even though your computer may not have a virus, it could contain spyware that can slow down your computer.  Also depending upon whether or not you have dial-up or cable modem, it could also be the amount of space that your computer has reserved for the internet.',
#  'Foam mattresses are pretty nice.  The Tempurpedic mattresses are great!',
#  'GOD is one and noone questions that. Its just that a few wise men with no so good intentions made religion to control people by saying things like God will punish you if you insulta a brahmin or maybe a Jew. . In India we have one religion and thats what binds us all and its called Cricket',
#  "Because it's cheaper than buying. Or for the thrill.",
#  'You can completely wipe a harddrive with a program called Dban Autonuke.  Or open Windows Explorer and select the files you want to remove and delete them.  make sure you clear your Recyle Bin.',
#  'Most repudible operators have 24/7/365 service, and take care of all outages quickly.  However all will have a "maintenance window" usually 1am-4am, during which they do work on the network.  During this time some services may not be available.',
#  "You'll have to set up the client to run on port 29.  If you can't use a configuration file to do so, you'll need to grab source code and recompile it to listen on port 29.  . . Note that most places turn off finger as they view it as a security risk.",
#  'dil·i·gent Pronunciation (dl-jnt). adj.. Marked by persevering, painstaking effort.',
#  "For iTunes 6 (don't know if it works with earlier versions), select all the files you want (edit->select all), click on copy, then paste them to a folder/USB drive/CD burner to transfer them to your new computer. You can then install iTunes on the new machine and import the files. Not sure what happens to tunes you've bought on iTunes, but I assume they'll work once your new computer has been registered.. . For playlists, use File->Export Library... or File->Export Song List... on the old machine and File->Import... on the new machine.",
#  'In proportion to our bodies, we have 10 fingers and 10 toes so that we can grip things and be able to walk properly. Can you imagine yourself missing a couple of fingers and toes and still be able to do everything properly?',
#  "Each country is in charge of determining time zones and each have passed laws to create them. They chose where they should go so that noon would basically coincide with the sun's highest point in the sky.",
#  "Connect to the internet first , on your taskbar go to the extreme right (you'll have the time there ) you will find an icon that reprsents two monitor screen blinking at different intervals of time . double click on them and u can get how much upload , download and time u have used the internet for (sorry for the grammatical mistakes)",
#  "why buy land that clearly had no purpose or meaning, clearly why it has been so long and you didn't keep up with the papers.  not trying to be mean but if it was just b/c u have the money share the wealth!!!!  but if i am wrong about all that good luck hopefully you may find the paper!",
#  'I use a program called Hamachi, it creates a Seure VPN that will connect to anyone who also has it installed.  There is noo need for a server as it is p2p, and also no need to forward any ports on the router.',
#  'Rayleigh scattering (named after Lord Rayleigh) is the scattering of light by particles much smaller than the wavelength of the light. It occurs when light travels in transparent solids and liquids, but is most prominently seen in gases. Rayleigh scattering of sunlight from particles in the atmosphere is one reason light from the sky is blue.',
#  "The soldier can give it to you. Not trying to be hateful, but if the soldier doesn't give it to you personally, if I was in the position of giving it to you I would be concerned. I would be wondering why the troop didn't want you to have it in the first place.",
#  '"The all seeing eye" this is the eye of god looking down on us. the writing at the bottom of the pyrmid is latin numerals meaning 1776 the date of our independence its at the base because it mean that is the base of our countary and the eye on top it showing god is on top and in control of our lifes and state. our founding fathers wanted us to remeber that god comes first and is even about us and state.',
#  'drink some ginger ale or club soda. . . Also, try Mylanta Gas Pills...you should find it at your local pharmacy.',
#  'Usually the grades from all your classes from 9th grade to 12th grade and the scores from any standardized tests you may have taken. I have seen my transcripts and never saw any record of things outside grades and scores.',
#  "The reason for life is to live for God all the way. Or if your asking why are we here, then I'll have to research that one.",
#  'many programs will allow you to bypass the pop up stopper by holding the control or shift button while clicking on the link that you want to come up.. . Of course, you can always disable the program in question temporarily until you are done with what your doing.',
#  'As the previous responders say, it means "in absence". This is most often applied to trials, where a person can be indicted, tried, and even convicted without being present. Because of the sixth amendment\'s protections, this is very rare in the United States. It usually can only happen if the defendent failed to show up to the trial.',
#  'An intolerable breach of citizens\' privacy!!! Suppose they see in you a person who is helping Irak to develop and build the mass destruction weapons Mr Bush "saw" there!!!? Well, just joking! But there is always the risk that data may  be used in a wrong and foul way.',
#  'Because most girls were stylish uncomfortable shoes all day to feel pretty. So at home, away from the judgement eyes of society they can be barefoot and comfortable.',
#  'The first law of economics:  Supply and Demand.  Low Supply + High Demand = High Price.',
#  'At one time dimes were made of silver.  The smaller size was because it was worth more than the nickel (which was made of nickel metal, a less expensive material).',
#  "You can accomplish what you need to do by using removable hard drives.  Each hard drive will have it's own carrier, which will plug into an installed frame in your computer.  Any reputable electronics store should be able to show you what you need to purchase.",
#  'Here the link for you!  It has instructions for what you need to do.',
#  'Short for Transmission Control Protocol/Internet Protocol, the suite of communications protocols used to connect hosts on the Internet. TCP/IP uses several protocols, the two main ones being TCP and IP. TCP/IP is built into the UNIX operating system and is used by the Internet, making it the de facto standard for transmitting data over networks. Even network operating systems that have their own protocols, such as Netware, also support TCP/IP.',
#  'The back and chest problems could be from having heavy backpacks with all your books in them. I have the same problem and I am still suffering from some of those symptoms and I believe it is from carrying heavy backpacks for all those years that we have been in school.',
#  "the man is holding you back from beating my rating, duuude.   : P. . Its just the rules.. but HEY.. I don't make 'em...",
#  "(Voice over Internet Protocol) - A category of hardware and software that enables people to use the Internet as the transmission medium for telephone calls. Voice data is sent in packets using rather than by traditional POTS circuits. One advantage of VoIP is that the telephone calls over the Internet do not incur a surcharge beyond what the user is paying for Internet access, much in the same way that the user doesn't pay for sending individual e-mails over the Internet.",
#  'because most of the earth is blue and it reflects with the sun. thats why there is no color at night',
#  'You can either be invited by an existing user or you can sign up using your mobile phone.  See links for more information.',
#  'To find your gift within you and give it to the world helping others out. This will help you find who you are and help you find direction. These are our inner goals, ideas, and innovation. Put all of these different gifts together -hopefully beneficial for us - and we reach our next level.',
#  'If God created a great angel with no free will, He will only have a powerful, beautiful robot. Remember, it was not just Lucifer, but 1/3 of the angels as well. Scriptures seem to point out that ALL angels are given free will to choose. However, they do not have access to salvation like we do while alive on earth.',
#  'it could be an ingrown eyelash; or possibly a peice of debri or something that has gotten stuck in a pore, and infected it. go to your local doctor or emergency room; they will be able to give you an ointment of sorts that will help it go away faster. if nothing else, they will usually go away on there own after not very long- days or weeks.. . anyway, i hope that helps!',
#  'There are many good recipes for aple pies but there are also some important things to remember that are usually not in the recipe. That is you should make sure the bottom of the crust will bake as well and not remain soggy. To do this, coat the inside of the crust with butter before adding the filling and place the baking dish on a dark metal pan so the bottom will get more heat.',
#  'Efficiently managing the strategy of a large scale organization is one of the most challenging task for executives. The Business Scenario Map shows the example of a strategy management scenario that takes place between Strategic Controlling, Business Unit Management, Operational Management and the HR Department. Improving the understanding for the strategy, increasing employee motivation and finally achieving better financial results are the key benefits of the implementation of this scenario.',
# ...
#  'Depends on which service you are using. Most chat services require that you are the host of the chatroom. If you made the chatroom then you are the host. Some services dont allow you to boot someone off the chatroom, like AIM.',
#  'This question has been answered for 2 months! Time to vote! The above link IS very informative and the DVD burning method would probably work well.',
#  'You may need to contact your city or county government for their requirements for business licensing.. . You may also need to register yourself as a business in your city, county or state.. . While "Mark Bertrand"s information was helpful to you, this answer is in violation of YA\'s Community Guidelines for solicitation.',
#  "Life has no meaning unless there is a Creator.  So I say, to find out the meaning of life, somehow connect with the Creator.  Now, that's a whole other question...",
#  'You can.  Use the mapping (x, y, z) -> x.  Of course, that is a many-to-one mapping, and kind of useless.',
#  "Make sure it is attached to your computer properly.  If it is, makes sure appropriate drivers are installed although your computer shouldn't not need them.  If all else fails, you can attempt to update the firmware of the defective drive if an upgrade exists.",
#  'Ive played the averages for the past ten weeks of each number set and I have won 238 dollars! Not bad!',
#  'I like Il Fornaio on Cowper Street, just off of University for fancy Italian food, and Pasta? on University for cheap meals.',
#  "Weblogs, or blogs, exist to log what's going on around the World Wide Web. A weblog is usually defined as a personal or noncommercial web site that uses a dated log format (usually with the most recent addition at the top of the page) and contains links to other web sites along with commentary about those sites. A weblog is updated frequently and sometimes groups links by specific subjects, such as politics, news, pop culture, or computer issues.",
#  '1) by asking more clear, specificated questions like "spysheriff" or "topsearch" or "trojan.abwiz" etc.. . 2) if you want to learn some programs, i advise hijackthis and xoftspy',
#  'It only works if you can recall things very well by learning them during class or reading, and that requires that you have paid close attention throughout the class.. . Occasionally, just common sense might help you along, but some teachers are more "tricky" with their exams than others.',
#  "Attorney's and Lawyers are the same thing.  Just like Cops and Police Officers.",
#  'DON\'T STEAL MUSIC! Most "free" downloads are illegal and you are stealing from artists.  Support the continuation of music you like and legally download music.',
#  'I recommend Yahoo! Games and the Free Internet Chess Server (FICS). FICS is a volunteer-run Internet chess server.',
#  'Althought spirituality may be associated with religion, a true spiritual person may have no religion at all.  On the other hand a relgious person may not be spiritual in the least. Sprituality to me is knowing one self and becoming one with your surroundings and nature.  Think ZEN.',
#  'They want to make sure that it is you.  SOmetimes if you are on any of the Yahoo pages and you are typing something or browsing something for too long, you get timed out.  So you have to sign in again with your password for security and privacy.',
#  'I looked on Google & found these slow-motion K-rail videos. Not an answer to your question but wow! Check \'em out, especially the "downstream" clips!! (see link below)',
#  'hydrogen bonds will increase the boiling point of a substance, all else being equal.. one way to see this is by looking at the boiling point of alcohols.. there is a near linear correlation between length fo the carbon chain and the boiling point for straight chain carbohydrate alcohols. as the chain gets shorter, the boiling point goes up faster than the linear relation would suggest, until you get to water  where hydrogen bonding is the most active and the boiling point jumps dramatically.',
#  'I like tabindex as it is much better than having a number of browser windows open. . . If you are browsing  a particular topic all the related links will be open in the other tabs very easy to open.. You can close all the tabs in one mouse click or close them individually at your will.',
#  "Not sure if you want to know how to make them yourself or how its done commercially.  But commercially its done by spinning them around in a large bowl that coats them a little bit at a time in many many layers.  (They usually then put a shiny layer on at the end too.) I believe there is a KitchenAid mixer attachment that lets you do it yourself at home, but I don't know how effective it is.",
#  'As a game developer you need to know that the end user who would be plying your game likes to get more risks and adventure. So your game has to slowly and steadily evolve',
#  '1.go to start->control panel->add remove programs-> remove yahoo messenger beta.. . 2.reinstall yahoo messenger stable version from the yahoo site.',
#  'This could be a very serious condition, see a doctor if this is happening to you.. It could mean that your intestines are bleeding (very serious). The higher up the bleeding is in the GI tract, the darker the stool will be. Or, it could be a high level of iron ingestion or certain medications, like pepto bismol.',
#  'If you are talking about "Yahoo Messenger," then you use the Buzz command to tell a friend that you want to chat.  . . I personally, think it\'s annoying.',
#  'Rayleigh scattering (named after Lord Rayleigh) is the scattering of light by particles much smaller than the wavelength of the light. It occurs when light travels in transparent solids and liquids, but is most prominently seen in gases. Rayleigh scattering of sunlight from particles in the atmosphere is one reason light from the sky is blue.',
#  'Most blood transfusions are of packed red cells and not serum/platelets or white cells.  Red cells have no nuclei/genetic material.  Blood type and rH factor are important and mismatch can yield a type of rejection.  The white cells are ultimately "rejected"   In someone with an inactive immune system (chemo patient) the blood can attack the recepient!',
#  "You may be experiencing a subconscious effort of your body trying to tell you to stop feeding it poison, or you made an ass of yourself. Or, since alcohol is a depressent, and guilt can be a result of a more depressed attitude, it really could be the alcohol. Take more vitamins to replace the ones you sapped, that could ease it... or don't drink alcohol. And yeah, I usually feel bad about drinking the next day 'cause it's bad for me and I make an ass out of myself.",
#  'The asp.net user is created when you install the .NET Framework. It is system controlled and is used for running .net services. It does not have administrator privileges.. . If you remove this user, you will not be able to do asp.net development on your machine.',
#  'that is a good question have you ever saw someone you love with someone else or they said something that makes you feel like you\'re on a roller coaster or your heart is going to beat out of your chest, or been so mad you actually feel the heat come from your body and you adrenaline going crazy, that is feeling. At the time you never go through the process of thinking "that hurt i am going to feel sick now or i am mad"  i think feeling is more of a non planned event that happens quickly and thinking is more rational, and patient.',
#  'Black Pope is a derogatory name given to the Superior General of the Society of Jesus, more commonly known as the Jesuits. The name comes partly from the color of the robes worn by members of the society and partly from a past misconception (most prominent around the 16th and 17th centuries) amongst Protestant European countries concerning the relative power of the Jesuits within the Roman Catholic Church.',
#  "There is no feature built into windows to do this and in fact I have seen several examples of actual coding you would have to do to enable that to work.  But and I don't know how effective it is but you might want to check out a freeware program call Minimize to Tray which has the ability to minimize any application to the system tray by adding a button to the title bar.",
#  'Did the computer come with discs for a "system restore"? If so, you can insert those, restart the computer, and chose to reinstall everything. It will give you a warning about that this is going to delete all your files, which is exactly what you want to do. Good luck.',
#  'What kind of food ? Tavern on the green, Four Seasons, Peter Lugers...there are hundreds...',
#  'Definition of tsunami: An ocean wave produced by a sub-marine earthquake, landslide, or volcanic eruption. These waves may reach enormous dimensions and have sufficient energy to travel across entire oceans.. . The first link below is a site dedicated to tsunamis. Check it out.',
#  'The North Star is directly above the planet. The North Pole does not rotate and that is why the North Star doesnt rotate and the others do because they are on the sides and the planet is rotating causing them to look like they are moving.',
#  'A Duck with a sore throut.. . Seriously.... . A Quark is.... Any of a group of six elementary particles having electric charges of a magnitude one-third or two-thirds that of the electron, regarded as constituents of all hadrons.',
#  'According to WebMD, "A sports hernia is an injury of the inguinal area caused by repetitive twisting and turning at high speed.". . Even more astounding is a lot of times the condition goes undiagnosed for an extended period of time as athletes tend to "play through the pain."',
#  'Lean manufacturing used low inventory levels and other techniques to produce goods only as needed.. . Get the book "Lean Thinking".  It\'s chock-full on the subject with case studies and all.',
#  "Don't worry too much about hurting her, she should get over it if you advise her that her bragging is making her look like a snob.  Friends shouldn't let other friends be snobs.",
#  'A futures contract is a financial contract in which two parties agree to exchange a set of financial instruments or physical commodities for future delivery at a specified price. By buying a futures contract you are agreeing to buy something has not yet been produced.. . Futures contracts and transactions in the futures market are extremely specuative and not for the risk adverse investor.',
#  'A install is like the foetus.It is the main package from which it makes itself into the complete functional program.Install are used because it is uncomfortable to distribute the whole program(coz they take a lot of space)Installs are compact.. A setup is used to set the properties of a particular program.. But the main area of confusion happens where these days "setup" is used as the anem of the file from which the program is installed,whick is most surely the basis of ur question.',
#  'u spelt it wrong !!. Parkinson\'s disease is one of the most common neurologic disorders of the elderly. The term "parkinsonism" refers to any condition that causes any combination of the types of movement abnormalities seen in Parkinson\'s disease by damaging or destroying dopamine neurons in a certain area of the brain.',
#  'Your computer cannot connect to the Yahoo! server. Their server may have been temporarily overloaded, or it could be your own internet connection.',
#  'Send as pictures instead of attatchments. Make sure your cursor is in the message part and then click on Insert on the top and choose pictures. It puts the pictures right inside their e-mail message.',
#  "In the womb, all humans (and otherwise) start as females. Eventually, the foetus will grow male genitalia if it's a genetic male, but doesn't lose the nipples.",
#  "Can't help this HOWEVER, I can tell you if it seems to be a MONDAY that everyone seems to miss change your pay day to Monday is stead of Thur-Fri. this way your guaranteed majority of them to be in the offc. on Monday. Holidays explain they will only be paid the holiday IF they work the day bef. and the day after depending on how you want to do this.",
#  'There is no tresadecaphobia, but there is triskaidekaphobia.  It is an abnormal fear of the number 13.',
#  'Risks vs. Reward.  Is there enough reward to justify the risk of my startup capital and my time?',
#  'I honestly think its because they drive everywhere and live in suburbia. A lot of parts of Europe have cities and rural areas, but not really \'suburbia\' as much as in the US.  Its easier to lose weight when you live in a city and walk everywhere, or live in the country and work on the land, but most people who move to the suburbs gain weight because their movement becomes limited to "to the car" and "from the car". Of course that\'s just my opinion!',
#  'If you need a ticket to attend a funeral, the airlines will help you to a large degree.. . You can also have a friend transfer their frequent flier miles to you.',
#  'I think this has the potential to create either a truly enlightened group or a horribly misinformed populace. :-)',
#  'Sneezing was a symptom of the plague back in shakespearean times. Most people who got the plague died, so saying "god bless you" was kind of like a prayer for the victim.',
#  "Originally a baker's dozen was when a baker would make enough dough for 12 loafs of bread and then use the extra dough he had left to make a little something extra. This extra dough made a 13th loaf and thus a baker's dozen. . Now it refers to anything that you want to talk about in a quantity of 13.",
#  'this will work and keep your computer from storing new searches:. . tools, internet options, clear history, delete cookies, delete files, then go to the content tab, click autocomplete and uncheck the boxes there then hit OK',
#  "They aren't, bulmia is a human-only thing. If your cat is throwing up, s/he may be sick. If s/he is eating something (like plants) to throw up, it's because of a hairball they want OUT, now. Call your vet and get some anti-hairball treats if possible.",
#  'Be firm, but not sarcastic or snide when people take advantage of you.If you feel like a mean person, it does not mean that other people think youre mean. Let the other people know that youre agitated, and talk to them calmly but firmly.',
#  '"foo", "bar", and "foobar" are generally used as place holders by programmers; a way of saying "[insert your code/variable/constant/etc. here]".  Depending on the context in which you find it in the example code, you would replace "foo" in your own code with a function, a string literal, a variable, and so on.. . I haven\'t come across "_(\'foo\')" in any of the PHP scripts I\'ve looked at, though, but it seems unlikely (given PHP\'s rules of syntax) that it could represent a function or an escape sequence by itself; more than likely, it\'s meant to be replaced by something in your own code.',
#  'Sure you can delete your history and cookie settings but the info is still in your registry and that means your busted!!!  Someone knows what you have been up to...',
#  "A really simple answer is that a jet engine sucks in air, compresses it, injects fuel into the compressed airstream, ignites the fuel, and the burning fuel/air mixture exits the rear of the engine, creating thrust that pushes the engine (and the airplane it's attached to) down the runway into the air.. . Of course, a more detailed answer could cover several large volumes of manuals covering all the small details.",
#  "I only fly ANA to Bangkok, it's probably not the cheapest, but for the money, it's the best.  They have a daily flight out of DC to Narita then to Bangkok.  Cheers!",
#  'Go to Dish Network Online. You can order online or search for a retailer.',
#  "Don't click on it many times, because that will open up a lot of windows of Firefox. Instead, click on it once and WAIT for it to open. If it still doesn't open, uninstall it and install it again.",
#  ...]

# %%
text = "what is the shortest path algorithm?"
device = "cuda:0"

inputs = tokenizer(text, return_tensors="pt").to(device)
outputs = model.generate(**inputs, max_new_tokens=50)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1473: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# what is the shortest path algorithm?
#  nobody can answer me?
# What is the shortest path algorithm?
# What is the shortest path algorithm? I'm not sure what you mean by "shortest path algorithm".
# What is the shortest path algorithm? I'
